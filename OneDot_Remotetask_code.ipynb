# %% [markdown]
# # E-commerce Car shop application

# %% [markdown]
# The Json file is not validated as is .Its found that the array should have been seperated by " , "and start with square brackets but when each line is tested it is validated .Hence we are reading the lines one by one. One could also make the file validated by adding {} and "," after every entry . Next step is we parse the json txt in file1 and run loop to read every single line and that could be accessed in rowData

# %% [markdown]
#  - Input File:.Json file
#  - rowData:Each entry of the .Json text of type <class 'dict'>
#  - Module required:json

# %%
import json
file1 = open('supplier_car.json', 'r')
Lines = file1.readlines()
for line in Lines:
    print("{}".format(line.strip()))
    r = line.strip()
    rowData = json.loads(r)
# Out:
# {"ID":"976.0","MakeText":"MERCEDES-BENZ","TypeName":"McLaren","TypeNameFull":"MERCEDES-BENZ SLR McLaren","ModelText":"SLR","ModelTypeText":"SLR McLaren","Attribute Names":"Seats","Attribute Values":"2","entity_id":"0001fda6-192b-46a8-bc08-0e833f904eed"}
# {"ID":"1059.0","MakeText":"MERCEDES-BENZ","TypeName":"ML 350 Inspiration","TypeNameFull":"MERCEDES-BENZ ML 350 Inspiration","ModelText":"ML 350","ModelTypeText":"ML 350 Inspiration","Attribute Names":"Hp","Attribute Values":"235","entity_id":"00107c2d-0071-4475-88f0-810133638b7e"}
# {"ID":"524.0","MakeText":"AUDI","TypeName":"S6 Avant quattro 4.2","TypeNameFull":"AUDI S6 Avant quattro 4.2","ModelText":"S6","ModelTypeText":"S6 Avant quattro 4.2","Attribute Names":"FuelTypeText","Attribute Values":"Benzin","entity_id":"00126794-a8ef-48fe-93d6-43cfc69fbfb6"}
# {"ID":"608.0","MakeText":"SAAB","TypeName":"9-3 2.0i-16 TS Aero","TypeNameFull":"SAAB 9-3 2.0i-16 TS Aero","ModelText":"9-3","ModelTypeText":"9-3 2.0i-16 TS Aero","Attribute Names":"Ccm","Attribute Values":"1985","entity_id":"00182529-1bf7-4f93-89fa-2e8e634b2c9d"}
# {"ID":"726.0","MakeText":"PORSCHE","TypeName":"911 Turbo Cabrio","TypeNameFull":"PORSCHE 911 Turbo Cabrio","ModelText":"911","ModelTypeText":"911 Turbo Cabrio","Attribute Names":"BodyColorText","Attribute Values":"schwarz mét.","entity_id":"002d30c2-43f6-4905-868f-160dbc445c56"}
# {"ID":"639.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 600","TypeNameFull":"MERCEDES-BENZ SL 600","ModelText":"SL 600","ModelTypeText":"SL 600","Attribute Names":"ConsumptionTotalText","Attribute Values":"14.4 l/100km","entity_id":"003fb8f2-829f-4c90-89b9-cf4920d95f64"}
# {"ID":"197.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 600","TypeNameFull":"MERCEDES-BENZ SL 600","ModelText":"SL 600","ModelTypeText":"SL 600","Attribute Names":"FuelTypeText","Attribute Values":"Benzin","entity_id":"00e599a3-bf05-4a3a-896d-814732d64a07"}
# {"ID":"939.0","MakeText":"CHEVROLET","TypeName":"Corvette 6.2","TypeNameFull":"CHEVROLET Corvette 6.2","ModelText":"CORVETTE","ModelTypeText":"Corvette 6.2","Attribute Names":"Doors","Attribute Values":"2","entity_id":"00e9838a-6c6b-4981-8f3f-5b7358eb02b1"}
# {"ID":"717.0","MakeText":"MATRA","TypeName":"SIMCA Bagheera Serie II","TypeNameFull":"MATRA SIMCA Bagheera Serie II","ModelText":null,"ModelTypeText":"SIMCA Bagheera Serie II","Attribute Names":"ConsumptionTotalText","Attribute Values":"null","entity_id":"0119d621-2be4-4468-a6be-cf26805bd603"}
# {"ID":"970.0","MakeText":"PORSCHE","TypeName":"Carrera GT","TypeNameFull":"PORSCHE Carrera GT","ModelText":"CARRERA GT","ModelTypeText":"Carrera GT","Attribute Names":"Ccm","Attribute Values":"5733","entity_id":"013d10a2-c604-47c4-a853-ed3c41447d1d"}
# {"ID":"34.0","MakeText":"MERCEDES-BENZ","TypeName":"S 65 AMG L","TypeNameFull":"MERCEDES-BENZ S 65 AMG L","ModelText":"S 65 AMG","ModelTypeText":"S 65 AMG L","Attribute Names":"FuelTypeText","Attribute Values":"Benzin","entity_id":"0203c183-0e70-434f-927a-5226acc4fba9"}
# {"ID":"411.0","MakeText":"BMW","TypeName":"Alpina Look","TypeNameFull":"BMW 323 Alpina Look","ModelText":"323","ModelTypeText":"323 Alpina Look","Attribute Names":"Hp","Attribute Values":"140","entity_id":"02268c2b-8da5-4cce-b2e5-97c2789f72f4"}
# {"ID":"487.0","MakeText":"RENAULT","TypeName":"Rennwagen","TypeNameFull":"RENAULT CLIO Rennwagen","ModelText":"CLIO","ModelTypeText":"CLIO Rennwagen","Attribute Names":"Co2EmissionText","Attribute Values":"null","entity_id":"0252a44a-f8e8-436e-9876-1ff27e0b6c7e"}
# {"ID":"937.0","MakeText":"BMW","TypeName":"M3","TypeNameFull":"BMW M3","ModelText":"M3","ModelTypeText":"M3","Attribute Names":"TransmissionTypeText","Attribute Values":"Schaltgetriebe manuell","entity_id":"02545f2f-85da-4dc9-ad47-f83d3c95b1d0"}
# {"ID":"1134.0","MakeText":"ROLLS-ROYCE","TypeName":"Phantom 6.7 V12","TypeNameFull":"ROLLS-ROYCE Phantom 6.7 V12","ModelText":"PHANTOM","ModelTypeText":"Phantom 6.7 V12","Attribute Names":"FirstRegYear","Attribute Values":"2004","entity_id":"027ccd26-dd40-47fa-84d5-1e6ff6139441"}
# {"ID":"249.0","MakeText":"PORSCHE","TypeName":"911 Carrera Targa","TypeNameFull":"PORSCHE 911 Carrera Targa","ModelText":"911","ModelTypeText":"911 Carrera Targa","Attribute Names":"Co2EmissionText","Attribute Values":"269 g/km","entity_id":"0290430c-7087-42c9-b364-82e7ed00ef79"}
# {"ID":"1109.0","MakeText":"ALFA ROMEO","TypeName":"1300 Junior","TypeNameFull":"ALFA ROMEO SPIDER 1300 Junior","ModelText":"SPIDER","ModelTypeText":"SPIDER 1300 Junior","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"02f9db49-d5b3-487d-8c59-462ecf2ff9d3"}
# {"ID":"1011.0","MakeText":"AUDI","TypeName":"RS6 Avant quattro","TypeNameFull":"AUDI RS6 Avant quattro","ModelText":"RS6","ModelTypeText":"RS6 Avant quattro","Attribute Names":"ConsumptionTotalText","Attribute Values":"14.6 l/100km","entity_id":"033f0731-3cb1-4c65-96d2-c9dc3ca7bd93"}
# {"ID":"1011.0","MakeText":"AUDI","TypeName":"RS6 Avant quattro","TypeNameFull":"AUDI RS6 Avant quattro","ModelText":"RS6","ModelTypeText":"RS6 Avant quattro","Attribute Names":"Seats","Attribute Values":"5","entity_id":"034f0b30-7735-4444-a0fb-78979da74df5"}
# {"ID":"373.0","MakeText":"SIMCA","TypeName":"Rallye2","TypeNameFull":"SIMCA Rallye2","ModelText":null,"ModelTypeText":"Rallye2","Attribute Names":"TransmissionTypeText","Attribute Values":"Schaltgetriebe","entity_id":"03824acb-663a-4cbf-84ed-b2f98bddd7a4"}
# {"ID":"806.0","MakeText":"HONDA","TypeName":"Accord Coupé V6 3.0i VTEC","TypeNameFull":"HONDA Accord Coupé V6 3.0i VTEC","ModelText":"ACCORD","ModelTypeText":"Accord Coupé V6 3.0i VTEC","Attribute Names":"FirstRegYear","Attribute Values":"1998","entity_id":"0399aa11-8d96-4f84-a29e-1a5a729c634a"}
# {"ID":"1043.0","MakeText":"VW","TypeName":"Phaeton 6.0 W12 4Motion","TypeNameFull":"VW Phaeton 6.0 W12 4Motion","ModelText":"PHAETON","ModelTypeText":"Phaeton 6.0 W12 4Motion","Attribute Names":"ConditionTypeText","Attribute Values":"Occasion","entity_id":"03c81a4d-911f-4c17-aa4f-133a32dfa987"}
# {"ID":"869.0","MakeText":"RENAULT","TypeName":"Alpine A310 V6","TypeNameFull":"RENAULT Alpine A310 V6","ModelText":"ALPINE","ModelTypeText":"Alpine A310 V6","Attribute Names":"Km","Attribute Values":"31000","entity_id":"03cd41db-6069-4445-b1ac-ba7445d75e48"}
# {"ID":"682.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 55 AMG","TypeNameFull":"MERCEDES-BENZ SL 55 AMG","ModelText":"SL 55 AMG","ModelTypeText":"SL 55 AMG","Attribute Names":"TransmissionTypeText","Attribute Values":"Automat","entity_id":"03d2fbd8-f7f5-4437-b65f-41a6e832d8f4"}
# {"ID":"679.0","MakeText":"AUDI","TypeName":"RS4 Avant 4.2 FSI quattro","TypeNameFull":"AUDI RS4 Avant 4.2 FSI quattro","ModelText":"RS4","ModelTypeText":"RS4 Avant 4.2 FSI quattro","Attribute Names":"DriveTypeText","Attribute Values":"Allrad","entity_id":"041d1cd7-2760-4a4a-8b9f-90714e951812"}
# {"ID":"804.0","MakeText":"MERCEDES-BENZ","TypeName":"S 320","TypeNameFull":"MERCEDES-BENZ S 320","ModelText":"S 320","ModelTypeText":"S 320","Attribute Names":"DriveTypeText","Attribute Values":"Hinterradantrieb","entity_id":"042fc20b-c041-47ca-9ca9-b987c0ac9f28"}
# {"ID":"1076.0","MakeText":"MERCEDES-BENZ","TypeName":"S 500","TypeNameFull":"MERCEDES-BENZ S 500","ModelText":"S 500","ModelTypeText":"S 500","Attribute Names":"Co2EmissionText","Attribute Values":"320 g/km","entity_id":"04421ec3-9127-4680-8d41-ff73efb9de29"}
# {"ID":"382.0","MakeText":"BMW","TypeName":"M3","TypeNameFull":"BMW M3","ModelText":"M3","ModelTypeText":"M3","Attribute Names":"InteriorColorText","Attribute Values":"mehrfarbig","entity_id":"04540f3b-9597-4f8e-96da-2ac20b0ad138"}
# {"ID":"346.0","MakeText":"MERCEDES-BENZ","TypeName":"SLK 200","TypeNameFull":"MERCEDES-BENZ SLK 200","ModelText":"SLK 200","ModelTypeText":"SLK 200","Attribute Names":"Km","Attribute Values":"13800","entity_id":"045d7024-e8da-4783-8f04-1ad49c36299a"}
# {"ID":"288.0","MakeText":"AUDI","TypeName":"RS6 Avant quattro","TypeNameFull":"AUDI RS6 Avant quattro","ModelText":"RS6","ModelTypeText":"RS6 Avant quattro","Attribute Names":"FirstRegYear","Attribute Values":"2002","entity_id":"045e1f7a-8348-4995-98e6-44c1b7cc1928"}
# {"ID":"830.0","MakeText":"SMART","TypeName":"Fortwo passion","TypeNameFull":"SMART Fortwo passion","ModelText":"FORTWO","ModelTypeText":"Fortwo passion","Attribute Names":"FirstRegYear","Attribute Values":"2003","entity_id":"0470fa06-1d66-46de-9351-3a5d7c847473"}
# {"ID":"454.0","MakeText":"FERRARI","TypeName":"F355 Spider","TypeNameFull":"FERRARI F355 Spider","ModelText":"F355","ModelTypeText":"F355 Spider","Attribute Names":"Hp","Attribute Values":"380","entity_id":"0483f1a5-ca23-4747-b623-f761754c5552"}
# {"ID":"913.0","MakeText":"ROLLS-ROYCE","TypeName":"Corniche","TypeNameFull":"ROLLS-ROYCE Corniche","ModelText":"CORNICHE","ModelTypeText":"Corniche","Attribute Names":"DriveTypeText","Attribute Values":"Hinterradantrieb","entity_id":"04a9777b-397e-4018-abc3-fe22c8003a43"}
# {"ID":"289.0","MakeText":"BMW","TypeName":"X5 4.4i","TypeNameFull":"BMW X5 4.4i","ModelText":"X5","ModelTypeText":"X5 4.4i","Attribute Names":"Ccm","Attribute Values":"4398","entity_id":"04fb638e-6d14-4675-958c-1ad257a0174c"}
# {"ID":"357.0","MakeText":"BMW","TypeName":"740i","TypeNameFull":"BMW 740i","ModelText":"740","ModelTypeText":"740i","Attribute Names":"Hp","Attribute Values":"286","entity_id":"05181343-7154-49af-a626-89e59756099a"}
# {"ID":"892.0","MakeText":"BMW-ALPINA","TypeName":"B7 (E28)","TypeNameFull":"BMW-ALPINA 5 SERIES B7 (E28)","ModelText":"5 SERIES","ModelTypeText":"5 SERIES B7 (E28)","Attribute Names":"FuelTypeText","Attribute Values":"Benzin","entity_id":"05d6cef4-1d9e-4b21-8023-ca4f269e6a76"}
# {"ID":"573.0","MakeText":"MERCEDES-BENZ","TypeName":"B 200 T Sailing Edition","TypeNameFull":"MERCEDES-BENZ B 200 T Sailing Edition","ModelText":"B 200","ModelTypeText":"B 200 T Sailing Edition","Attribute Names":"Seats","Attribute Values":"5","entity_id":"060b7705-73b8-4728-80aa-2953de6ac903"}
# {"ID":"352.0","MakeText":"AUDI","TypeName":"RS6 Avant quattro","TypeNameFull":"AUDI RS6 Avant quattro","ModelText":"RS6","ModelTypeText":"RS6 Avant quattro","Attribute Names":"ConsumptionRatingText","Attribute Values":"G","entity_id":"061100df-9b36-46fa-951a-8d3feb0d2704"}
# {"ID":"205.0","MakeText":"FERRARI","TypeName":"F360 Modena Berlinetta","TypeNameFull":"FERRARI F360 Modena Berlinetta","ModelText":"F360","ModelTypeText":"F360 Modena Berlinetta","Attribute Names":"Seats","Attribute Values":"2","entity_id":"06534805-71c6-44fe-baea-b6472f191f8b"}
# {"ID":"718.0","MakeText":"FERRARI","TypeName":"456 GTA","TypeNameFull":"FERRARI 456 GTA","ModelText":"456","ModelTypeText":"456 GTA","Attribute Names":"ConsumptionRatingText","Attribute Values":"null","entity_id":"065f840c-3975-4523-aed5-c94ca170fd6a"}
# {"ID":"800.0","MakeText":"BMW","TypeName":"525i","TypeNameFull":"BMW 525i","ModelText":"525","ModelTypeText":"525i","Attribute Names":"FuelTypeText","Attribute Values":"Benzin","entity_id":"067b80dc-5b33-411e-a97d-6d1a4114168d"}
# {"ID":"456.0","MakeText":"MERCEDES-BENZ","TypeName":"S 63 AMG","TypeNameFull":"MERCEDES-BENZ S 63 AMG","ModelText":"S 63 AMG","ModelTypeText":"S 63 AMG","Attribute Names":"ConsumptionTotalText","Attribute Values":"10.1 l/100km","entity_id":"06d18fb1-002d-4091-b464-ceca62f0f851"}
# {"ID":"248.0","MakeText":"MASERATI","TypeName":"Spyder GT","TypeNameFull":"MASERATI Spyder GT","ModelText":"SPYDER GT","ModelTypeText":"Spyder GT","Attribute Names":"Seats","Attribute Values":"2","entity_id":"06d5b07f-9ac1-42f1-a80c-f8632df607f7"}
# {"ID":"164.0","MakeText":"MERCEDES-BENZ","TypeName":"E 55 AMG Avantgarde","TypeNameFull":"MERCEDES-BENZ E 55 AMG Avantgarde","ModelText":"E 55 AMG","ModelTypeText":"E 55 AMG Avantgarde","Attribute Names":"Km","Attribute Values":"35000","entity_id":"06e65f61-b2c8-4378-a929-e3f96159ceaf"}
# {"ID":"778.0","MakeText":"AUDI","TypeName":"RS6 Avant 5.0 V10 quattro","TypeNameFull":"AUDI RS6 Avant 5.0 V10 quattro","ModelText":"RS6","ModelTypeText":"RS6 Avant 5.0 V10 quattro","Attribute Names":"ConsumptionTotalText","Attribute Values":"14.0 l/100km","entity_id":"0716854b-2c14-40d3-b547-1add3486b320"}
# {"ID":"623.0","MakeText":"MERCEDES-BENZ","TypeName":"S 500","TypeNameFull":"MERCEDES-BENZ S 500","ModelText":"S 500","ModelTypeText":"S 500","Attribute Names":"FirstRegYear","Attribute Values":"2005","entity_id":"072c51e3-63d1-4e59-ae3a-b1f0ca198c23"}
# {"ID":"171.0","MakeText":"RENAULT","TypeName":"Alpine A310 V6","TypeNameFull":"RENAULT Alpine A310 V6","ModelText":"ALPINE","ModelTypeText":"Alpine A310 V6","Attribute Names":"FuelTypeText","Attribute Values":"Benzin","entity_id":"072f08f9-baa9-44c6-ad85-94a4810f7938"}
# {"ID":"506.0","MakeText":"MERCEDES-BENZ","TypeName":"E 50 AMG Avantgarde","TypeNameFull":"MERCEDES-BENZ E 50 AMG Avantgarde","ModelText":"E 50 AMG","ModelTypeText":"E 50 AMG Avantgarde","Attribute Names":"BodyColorText","Attribute Values":"rot mét.","entity_id":"07340e8a-2cd7-411e-9317-c366ef5b6605"}
# {"ID":"337.0","MakeText":"BMW","TypeName":"740i","TypeNameFull":"BMW 740i","ModelText":"740","ModelTypeText":"740i","Attribute Names":"ConsumptionRatingText","Attribute Values":"null","entity_id":"074869c6-4950-4719-8522-ba8a465b2be5"}
# {"ID":"858.0","MakeText":"CHEVROLET","TypeName":"Corvette ZR1","TypeNameFull":"CHEVROLET Corvette ZR1","ModelText":"CORVETTE","ModelTypeText":"Corvette ZR1","Attribute Names":"DriveTypeText","Attribute Values":"Hinterradantrieb","entity_id":"078f0145-ddd5-46cc-b44d-3f9173e26651"}
# {"ID":"532.0","MakeText":"AUDI","TypeName":"S8 4.2 quattro","TypeNameFull":"AUDI S8 4.2 quattro","ModelText":"S8","ModelTypeText":"S8 4.2 quattro","Attribute Names":"BodyColorText","Attribute Values":"schwarz","entity_id":"0819d259-525d-4914-af5d-63bc116db2bb"}
# {"ID":"509.0","MakeText":"BMW","TypeName":"135i","TypeNameFull":"BMW 135i","ModelText":"135","ModelTypeText":"135i","Attribute Names":"BodyColorText","Attribute Values":"schwarz","entity_id":"082a8951-5e9a-46d6-b486-8999824c4cfc"}
# {"ID":"357.0","MakeText":"BMW","TypeName":"740i","TypeNameFull":"BMW 740i","ModelText":"740","ModelTypeText":"740i","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"08636f3f-915b-43a4-acff-47cbd0a4ac5e"}
# {"ID":"536.0","MakeText":"BMW","TypeName":"320i Touring","TypeNameFull":"BMW 320i Touring","ModelText":"320","ModelTypeText":"320i Touring","Attribute Names":"ConditionTypeText","Attribute Values":"Occasion","entity_id":"086eb3b0-e14f-46bb-9cae-40ed451716ad"}
# {"ID":"919.0","MakeText":"BMW","TypeName":"M5","TypeNameFull":"BMW M5","ModelText":"M5","ModelTypeText":"M5","Attribute Names":"Hp","Attribute Values":"503","entity_id":"0870a281-f5f4-42e5-a5da-11db7ecc9c27"}
# {"ID":"141.0","MakeText":"MERCEDES-BENZ","TypeName":"C 230 Elégance","TypeNameFull":"MERCEDES-BENZ C 230 Elégance","ModelText":"C 230","ModelTypeText":"C 230 Elégance","Attribute Names":"FirstRegMonth","Attribute Values":"2","entity_id":"088a545c-6b8d-4435-b97e-8c1e12abf3b7"}
# {"ID":"917.0","MakeText":"BMW","TypeName":"750iL","TypeNameFull":"BMW 750iL","ModelText":"750","ModelTypeText":"750iL","Attribute Names":"BodyColorText","Attribute Values":"silber mét.","entity_id":"0896637d-4997-45a8-b3cb-e396af477743"}
# {"ID":"686.0","MakeText":"TOYOTA","TypeName":"Bergungsfahrzeug","TypeNameFull":"TOYOTA DYNA Bergungsfahrzeug","ModelText":"DYNA","ModelTypeText":"DYNA Bergungsfahrzeug","Attribute Names":"City","Attribute Values":"Zuzwil","entity_id":"08abcaaa-9b53-477d-b8e1-3b85b2d1058b"}
# {"ID":"1014.0","MakeText":"ALFA ROMEO","TypeName":"Coupé","TypeNameFull":"ALFA ROMEO 8C Coupé","ModelText":"8C","ModelTypeText":"8C Coupé","Attribute Names":"Doors","Attribute Values":"2","entity_id":"094e82cf-0516-4870-8bb5-971d493ee2bf"}
# {"ID":"517.0","MakeText":"LAMBORGHINI","TypeName":"Gallardo LP570-4 Coupé SL","TypeNameFull":"LAMBORGHINI Gallardo LP570-4 Coupé SL","ModelText":"GALLARDO","ModelTypeText":"Gallardo LP570-4 Coupé SL","Attribute Names":"ConsumptionTotalText","Attribute Values":"13.7 l/100km","entity_id":"0950de5b-8946-496f-8fbc-f934526eb762"}
# {"ID":"256.0","MakeText":"FERRARI","TypeName":"F360 Spider","TypeNameFull":"FERRARI F360 Spider","ModelText":"F360","ModelTypeText":"F360 Spider","Attribute Names":"ConsumptionRatingText","Attribute Values":"G","entity_id":"095a20e7-186b-46a2-b81e-13c5ba4582d1"}
# {"ID":"719.0","MakeText":"LAMBORGHINI","TypeName":"Murciélago 6.2 Coupé","TypeNameFull":"LAMBORGHINI Murciélago 6.2 Coupé","ModelText":"MURCIÉLAGO","ModelTypeText":"Murciélago 6.2 Coupé","Attribute Names":"TransmissionTypeText","Attribute Values":"Schaltgetriebe manuell","entity_id":"096d8056-07c2-4cd3-a072-ae5f230a0a00"}
# {"ID":"207.0","MakeText":"MERCEDES-BENZ","TypeName":"E 55 AMG Avantgarde","TypeNameFull":"MERCEDES-BENZ E 55 AMG Avantgarde","ModelText":"E 55 AMG","ModelTypeText":"E 55 AMG Avantgarde","Attribute Names":"TransmissionTypeText","Attribute Values":"Automat","entity_id":"09c0a99e-c920-4965-8243-b2c8066e07bf"}
# {"ID":"829.0","MakeText":"MASERATI","TypeName":"GranTurismo","TypeNameFull":"MASERATI GranTurismo","ModelText":"GRANTURISMO","ModelTypeText":"GranTurismo","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\", \"Direkt-/Parallelimport\"","entity_id":"09fb37a7-d317-4a79-91bc-32af67400a04"}
# {"ID":"874.0","MakeText":"FERRARI","TypeName":"575M","TypeNameFull":"FERRARI 575M","ModelText":"575M","ModelTypeText":"575M","Attribute Names":"TransmissionTypeText","Attribute Values":"Automatik-Getriebe","entity_id":"0a016f95-5ba5-4e0f-aedb-d2723fe68d9d"}
# {"ID":"48.0","MakeText":"TRIUMPH","TypeName":"MK IV","TypeNameFull":"TRIUMPH Spitfire MK IV","ModelText":"Spitfire","ModelTypeText":"Spitfire MK IV","Attribute Names":"ConsumptionTotalText","Attribute Values":"null","entity_id":"0a15c96b-7790-4b4a-87bf-93338d62b19f"}
# {"ID":"548.0","MakeText":"FERRARI","TypeName":"456M GTA","TypeNameFull":"FERRARI 456M GTA","ModelText":"456","ModelTypeText":"456M GTA","Attribute Names":"Seats","Attribute Values":"4","entity_id":"0ab28c16-6cf5-4f5e-816e-6f4c3af18a06"}
# {"ID":"647.0","MakeText":"PORSCHE","TypeName":"Cayenne Turbo","TypeNameFull":"PORSCHE Cayenne Turbo","ModelText":"CAYENNE","ModelTypeText":"Cayenne Turbo","Attribute Names":"Ccm","Attribute Values":"4511","entity_id":"0ae00d86-5490-4e19-91e7-58b02b00dcc2"}
# {"ID":"208.0","MakeText":"BMW","TypeName":"M3","TypeNameFull":"BMW M3","ModelText":"M3","ModelTypeText":"M3","Attribute Names":"ConsumptionRatingText","Attribute Values":"G","entity_id":"0bed5a6a-a190-4a69-9a5f-2fb12f18f3c6"}
# {"ID":"965.0","MakeText":"BMW","TypeName":"M5","TypeNameFull":"BMW M5","ModelText":"M5","ModelTypeText":"M5","Attribute Names":"ConditionTypeText","Attribute Values":"Occasion","entity_id":"0befa7a4-9826-45d4-9404-436729de1532"}
# {"ID":"612.0","MakeText":"MERCEDES-BENZ","TypeName":"CL 500","TypeNameFull":"MERCEDES-BENZ CL 500","ModelText":"CL 500","ModelTypeText":"CL 500","Attribute Names":"ConsumptionRatingText","Attribute Values":"G","entity_id":"0c0cad4e-854a-46da-a3eb-67c2b28a21ec"}
# {"ID":"479.0","MakeText":"MERCEDES-BENZ","TypeName":"CL 600","TypeNameFull":"MERCEDES-BENZ CL 600","ModelText":"CL 600","ModelTypeText":"CL 600","Attribute Names":"ConsumptionRatingText","Attribute Values":"null","entity_id":"0c598117-e97f-4f37-9924-c8ad80bd2395"}
# {"ID":"360.0","MakeText":"TALBOT","TypeName":"Murena 2.2","TypeNameFull":"TALBOT Murena 2.2","ModelText":"MATRA","ModelTypeText":"Murena 2.2","Attribute Names":"Hp","Attribute Values":"118","entity_id":"0c765e6a-f179-4307-b847-2733ccd6c500"}
# {"ID":"734.0","MakeText":"AUDI","TypeName":"RS4 Avant quattro","TypeNameFull":"AUDI RS4 Avant quattro","ModelText":"RS4","ModelTypeText":"RS4 Avant quattro","Attribute Names":"Ccm","Attribute Values":"2671","entity_id":"0c8fba13-6b6f-4404-8bdd-e10efdbf0e4b"}
# {"ID":"997.0","MakeText":"AUDI","TypeName":"RS6 Avant 5.0 V10 quattro","TypeNameFull":"AUDI RS6 Avant 5.0 V10 quattro","ModelText":"RS6","ModelTypeText":"RS6 Avant 5.0 V10 quattro","Attribute Names":"BodyTypeText","Attribute Values":"Kombi","entity_id":"0ceaef13-ae34-4e9a-b7f2-dab97ef7c430"}
# {"ID":"880.0","MakeText":"RENAULT","TypeName":"Windschutzscheibe","TypeNameFull":"RENAULT SPORT SPIDER Windschutzscheibe","ModelText":"SPORT SPIDER","ModelTypeText":"SPORT SPIDER Windschutzscheibe","Attribute Names":"FirstRegYear","Attribute Values":"2000","entity_id":"0d314b93-8e98-48e9-ac32-e061c739d2e8"}
# {"ID":"532.0","MakeText":"AUDI","TypeName":"S8 4.2 quattro","TypeNameFull":"AUDI S8 4.2 quattro","ModelText":"S8","ModelTypeText":"S8 4.2 quattro","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"0d3ba52e-9fec-47b8-a84e-9bcd4de1ce20"}
# {"ID":"830.0","MakeText":"SMART","TypeName":"Fortwo passion","TypeNameFull":"SMART Fortwo passion","ModelText":"FORTWO","ModelTypeText":"Fortwo passion","Attribute Names":"Doors","Attribute Values":"3","entity_id":"0e2c89f7-20b5-40b6-9026-ec0e127b6efb"}
# {"ID":"35.0","MakeText":"MERCEDES-BENZ","TypeName":"CLS 500","TypeNameFull":"MERCEDES-BENZ CLS 500","ModelText":"CLS 500","ModelTypeText":"CLS 500","Attribute Names":"BodyColorText","Attribute Values":"anthrazit mét.","entity_id":"0e95a983-d749-4b42-a667-9dd27d0fb5a6"}
# {"ID":"175.0","MakeText":"AUDI","TypeName":"RS6 Avant quattro","TypeNameFull":"AUDI RS6 Avant quattro","ModelText":"RS6","ModelTypeText":"RS6 Avant quattro","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"0e98344a-5c83-43e5-a194-7c75340bf2ff"}
# {"ID":"796.0","MakeText":"AUDI","TypeName":"R8 Coupé 5.2","TypeNameFull":"AUDI R8 Coupé 5.2","ModelText":"R8","ModelTypeText":"R8 Coupé 5.2","Attribute Names":"BodyColorText","Attribute Values":"schwarz mét.","entity_id":"0e9b6f88-a0db-4afd-804b-83740c89a5f6"}
# {"ID":"727.0","MakeText":"BMW","TypeName":"550i Touring","TypeNameFull":"BMW 550i Touring","ModelText":"550","ModelTypeText":"550i Touring","Attribute Names":"TransmissionTypeText","Attribute Values":"Automat sequentiell","entity_id":"0f1e780c-98f9-4000-9cc9-3389a8409f96"}
# {"ID":"721.0","MakeText":"PORSCHE","TypeName":"911 Turbo","TypeNameFull":"PORSCHE 911 Turbo","ModelText":"911","ModelTypeText":"911 Turbo","Attribute Names":"FirstRegMonth","Attribute Values":"1","entity_id":"0f4822a8-855f-490a-b22c-6aa2705287da"}
# {"ID":"450.0","MakeText":"PORSCHE","TypeName":"944 S2 Cabriolet ABS","TypeNameFull":"PORSCHE 944 S2 Cabriolet ABS","ModelText":"944","ModelTypeText":"944 S2 Cabriolet ABS","Attribute Names":"Ccm","Attribute Values":"2989","entity_id":"0f64d09a-4ec5-40e5-9869-367e741d164e"}
# {"ID":"310.0","MakeText":"RENAULT","TypeName":"R8 Gordini","TypeNameFull":"RENAULT R8 Gordini","ModelText":null,"ModelTypeText":"R8 Gordini","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"0fe351e2-fa83-435c-b6df-97bb32bc6264"}
# {"ID":"929.0","MakeText":"LAND ROVER","TypeName":"Discovery 3.9","TypeNameFull":"LAND ROVER Discovery 3.9","ModelText":"DISCOVERY","ModelTypeText":"Discovery 3.9","Attribute Names":"ConsumptionTotalText","Attribute Values":"16.4 l/100km","entity_id":"0ff25ae9-c9ef-4aed-a96b-1ef9074c5c08"}
# {"ID":"338.0","MakeText":"LAMBORGHINI","TypeName":"Gallardo LP560-4 Spyder","TypeNameFull":"LAMBORGHINI Gallardo LP560-4 Spyder","ModelText":"GALLARDO","ModelTypeText":"Gallardo LP560-4 Spyder","Attribute Names":"FirstRegYear","Attribute Values":"2011","entity_id":"10478901-c787-4bc5-838f-9da07e32d7ae"}
# {"ID":"866.0","MakeText":"McLAREN","TypeName":"MP4-12C Coupé 3.8 V8","TypeNameFull":"McLAREN MP4-12C Coupé 3.8 V8","ModelText":"12C","ModelTypeText":"MP4-12C Coupé 3.8 V8","Attribute Names":"BodyColorText","Attribute Values":"silber mét.","entity_id":"1080b451-db0a-4034-b53c-b24df6b10997"}
# {"ID":"979.0","MakeText":"PORSCHE","TypeName":"911 Turbo","TypeNameFull":"PORSCHE 911 Turbo","ModelText":"911","ModelTypeText":"911 Turbo","Attribute Names":"FirstRegMonth","Attribute Values":"6","entity_id":"10876713-1121-441b-93d7-86509c613830"}
# {"ID":"1025.0","MakeText":"CHEVROLET","TypeName":"Corvette Z06","TypeNameFull":"CHEVROLET Corvette Z06","ModelText":"CORVETTE","ModelTypeText":"Corvette Z06","Attribute Names":"BodyColorText","Attribute Values":"silber mét.","entity_id":"109979d7-76b7-42ba-a842-5a0c3846858c"}
# {"ID":"516.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 500","TypeNameFull":"MERCEDES-BENZ SL 500","ModelText":"SL 500","ModelTypeText":"SL 500","Attribute Names":"TransmissionTypeText","Attribute Values":"Automat","entity_id":"109d0004-98b1-4070-a4bd-d7d9902e1f43"}
# {"ID":"541.0","MakeText":"RENAULT","TypeName":"1600 S","TypeNameFull":"RENAULT Alpine A110 1600 S","ModelText":"Alpine A110","ModelTypeText":"Alpine A110 1600 S","Attribute Names":"Hp","Attribute Values":"124","entity_id":"10c07596-a648-4188-ab86-8c61d46b24c9"}
# {"ID":"538.0","MakeText":"BMW","TypeName":"525xi","TypeNameFull":"BMW 525xi","ModelText":"525","ModelTypeText":"525xi","Attribute Names":"BodyColorText","Attribute Values":"schwarz","entity_id":"10ca5190-9f61-40dd-886d-f452cd97408b"}
# {"ID":"976.0","MakeText":"MERCEDES-BENZ","TypeName":"McLaren","TypeNameFull":"MERCEDES-BENZ SLR McLaren","ModelText":"SLR","ModelTypeText":"SLR McLaren","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"10f256ec-800b-44d1-8645-a80cc3ba227f"}
# {"ID":"96.0","MakeText":"JAGUAR","TypeName":"XJ 4.0 Sovereign","TypeNameFull":"JAGUAR XJ 4.0 Sovereign","ModelText":"XJ","ModelTypeText":"XJ 4.0 Sovereign","Attribute Names":"Hp","Attribute Values":"241","entity_id":"10fcd9c6-be61-4cd3-b92b-ecfd764ca2e3"}
# {"ID":"408.0","MakeText":"MERCEDES-BENZ","TypeName":"CLK 55 AMG Avantgarde","TypeNameFull":"MERCEDES-BENZ CLK 55 AMG Avantgarde","ModelText":"CLK 55 AMG","ModelTypeText":"CLK 55 AMG Avantgarde","Attribute Names":"FuelTypeText","Attribute Values":"Benzin","entity_id":"111e42a5-104b-44a3-b30c-52233a06a273"}
# {"ID":"598.0","MakeText":"JAGUAR","TypeName":"XKR S/C","TypeNameFull":"JAGUAR XKR S/C","ModelText":"XK","ModelTypeText":"XKR S/C","Attribute Names":"BodyColorText","Attribute Values":"schwarz","entity_id":"1134476a-920e-4169-8fc0-30cd2b914ada"}
# {"ID":"557.0","MakeText":"PORSCHE","TypeName":"911 GT3 RS","TypeNameFull":"PORSCHE 911 GT3 RS","ModelText":"911","ModelTypeText":"911 GT3 RS","Attribute Names":"BodyTypeText","Attribute Values":"Coupé","entity_id":"11381c2d-fd3d-44c3-a2c1-7fd9985d40da"}
# {"ID":"716.0","MakeText":"BMW","TypeName":"540i","TypeNameFull":"BMW 540i","ModelText":"540","ModelTypeText":"540i","Attribute Names":"Seats","Attribute Values":"5","entity_id":"11547d11-cc52-40a4-91a8-a2b819464549"}
# {"ID":"91.0","MakeText":"BENTLEY","TypeName":"Continental FlyingSpur6.0","TypeNameFull":"BENTLEY Continental FlyingSpur6.0","ModelText":"CONTINENTAL","ModelTypeText":"Continental FlyingSpur6.0","Attribute Names":"Doors","Attribute Values":"4","entity_id":"11b36846-2577-4467-8941-cb3cae9cfa8a"}
# {"ID":"52.0","MakeText":"MERCEDES-BENZ","TypeName":"CLS 500","TypeNameFull":"MERCEDES-BENZ CLS 500","ModelText":"CLS 500","ModelTypeText":"CLS 500","Attribute Names":"City","Attribute Values":"Zuzwil","entity_id":"11ca4c6b-cc23-420f-ae27-8b529540c524"}
# {"ID":"709.0","MakeText":"BENTLEY","TypeName":"Continental GT 6.0","TypeNameFull":"BENTLEY Continental GT 6.0","ModelText":"CONTINENTAL","ModelTypeText":"Continental GT 6.0","Attribute Names":"BodyColorText","Attribute Values":"schwarz mét.","entity_id":"11e86976-49ec-4ec1-a167-fa8247505d04"}
# {"ID":"550.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 500","TypeNameFull":"MERCEDES-BENZ SL 500","ModelText":"SL 500","ModelTypeText":"SL 500","Attribute Names":"Hp","Attribute Values":"320","entity_id":"121d4859-3910-4393-89a5-5859290c8ed1"}
# {"ID":"5.0","MakeText":"PORSCHE","TypeName":"Cayenne Turbo Techart Magnum Kit","TypeNameFull":"PORSCHE Cayenne Turbo Techart Magnum Kit","ModelText":"CAYENNE","ModelTypeText":"Cayenne Turbo Techart Magnum Kit","Attribute Names":"FirstRegYear","Attribute Values":"2010","entity_id":"1255ad85-ac71-418b-a69c-bb4dda28e6a6"}
# {"ID":"96.0","MakeText":"JAGUAR","TypeName":"XJ 4.0 Sovereign","TypeNameFull":"JAGUAR XJ 4.0 Sovereign","ModelText":"XJ","ModelTypeText":"XJ 4.0 Sovereign","Attribute Names":"TransmissionTypeText","Attribute Values":"Automat","entity_id":"125c9b21-d9d2-4621-bba6-8c7ad2398797"}
# {"ID":"248.0","MakeText":"MASERATI","TypeName":"Spyder GT","TypeNameFull":"MASERATI Spyder GT","ModelText":"SPYDER GT","ModelTypeText":"Spyder GT","Attribute Names":"Doors","Attribute Values":"2","entity_id":"12a7ead4-1c67-447f-8333-bdc64b287e94"}
# {"ID":"438.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 60","TypeNameFull":"MERCEDES-BENZ SL 60","ModelText":null,"ModelTypeText":"SL 60","Attribute Names":"City","Attribute Values":"Zuzwil","entity_id":"12ed84b8-08f5-436b-acb1-4dbfa14e7795"}
# {"ID":"212.0","MakeText":"BMW","TypeName":"Z4 2.5i Roadster","TypeNameFull":"BMW Z4 2.5i Roadster","ModelText":"Z4","ModelTypeText":"Z4 2.5i Roadster","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"131b93a1-50b4-4861-8818-812f5e31d87f"}
# {"ID":"954.0","MakeText":"AUDI","TypeName":"RS6 Avant quattro","TypeNameFull":"AUDI RS6 Avant quattro","ModelText":"RS6","ModelTypeText":"RS6 Avant quattro","Attribute Names":"BodyTypeText","Attribute Values":"Kombi","entity_id":"132542e0-3ac3-40ee-bbf6-026e29fef9ff"}
# {"ID":"566.0","MakeText":"MERCEDES-BENZ","TypeName":"S 55 AMG","TypeNameFull":"MERCEDES-BENZ S 55 AMG","ModelText":"S 55 AMG","ModelTypeText":"S 55 AMG","Attribute Names":"TransmissionTypeText","Attribute Values":"Automat","entity_id":"13550787-4913-4723-ae45-15b4838cf0f6"}
# {"ID":"581.0","MakeText":"RENAULT","TypeName":"R5 1400 Alpine Turbo","TypeNameFull":"RENAULT R5 1400 Alpine Turbo","ModelText":"R5","ModelTypeText":"R5 1400 Alpine Turbo","Attribute Names":"BodyTypeText","Attribute Values":"Kleinwagen","entity_id":"13832809-ce6d-43aa-9003-f05bf2d4e6e6"}
# {"ID":"665.0","MakeText":"AUDI","TypeName":"S5 Coupé 4.2 FSI quattro","TypeNameFull":"AUDI S5 Coupé 4.2 FSI quattro","ModelText":"S5","ModelTypeText":"S5 Coupé 4.2 FSI quattro","Attribute Names":"FirstRegYear","Attribute Values":"2008","entity_id":"1390dc39-6cb8-448d-9195-dce48c7e810c"}
# {"ID":"933.0","MakeText":"LANCIA","TypeName":"Monte Carlo 137 AS","TypeNameFull":"LANCIA Monte Carlo 137 AS","ModelText":null,"ModelTypeText":"Monte Carlo 137 AS","Attribute Names":"DriveTypeText","Attribute Values":"Vorderradantrieb","entity_id":"139432d5-e3b1-4dc1-91a1-b1938c3928c3"}
# {"ID":"1015.0","MakeText":"MERCEDES-BENZ","TypeName":"ML 400 CDI","TypeNameFull":"MERCEDES-BENZ ML 400 CDI","ModelText":"ML 400","ModelTypeText":"ML 400 CDI","Attribute Names":"TransmissionTypeText","Attribute Values":"Automat","entity_id":"1395513f-9c27-40d8-8fbe-e8d8039b91ec"}
# {"ID":"612.0","MakeText":"MERCEDES-BENZ","TypeName":"CL 500","TypeNameFull":"MERCEDES-BENZ CL 500","ModelText":"CL 500","ModelTypeText":"CL 500","Attribute Names":"Km","Attribute Values":"27800","entity_id":"13a93460-58d0-472b-a8c6-a4648a875a3e"}
# {"ID":"512.0","MakeText":"MERCEDES-BENZ","TypeName":"S 600","TypeNameFull":"MERCEDES-BENZ S 600","ModelText":"S 600","ModelTypeText":"S 600","Attribute Names":"ConsumptionTotalText","Attribute Values":"null","entity_id":"13c04801-febc-444a-8309-ab2e80dd6e8f"}
# {"ID":"626.0","MakeText":"MERCEDES-BENZ","TypeName":"S 63 AMG L","TypeNameFull":"MERCEDES-BENZ S 63 AMG L","ModelText":"S 63 AMG","ModelTypeText":"S 63 AMG L","Attribute Names":"TransmissionTypeText","Attribute Values":"Automat sequentiell","entity_id":"13fb7d18-da49-459f-82f2-dcae7b69b829"}
# {"ID":"226.0","MakeText":"MERCEDES-BENZ","TypeName":"190 E 2.5-16 Evo II ABS","TypeNameFull":"MERCEDES-BENZ 190 E 2.5-16 Evo II ABS","ModelText":"190","ModelTypeText":"190 E 2.5-16 Evo II ABS","Attribute Names":"FirstRegYear","Attribute Values":"1991","entity_id":"1415dbf6-9448-41dd-9a3c-a94fc77b3247"}
# {"ID":"86.0","MakeText":"DAIHATSU","TypeName":"Charade 1.0 Turbo","TypeNameFull":"DAIHATSU Charade 1.0 Turbo","ModelText":"CHARADE","ModelTypeText":"Charade 1.0 Turbo","Attribute Names":"BodyTypeText","Attribute Values":"Kleinwagen","entity_id":"14948b63-7ad7-4fd9-b6e6-57a458f58508"}
# {"ID":"725.0","MakeText":"BMW","TypeName":"M6","TypeNameFull":"BMW M6","ModelText":"M6","ModelTypeText":"M6","Attribute Names":"ConsumptionRatingText","Attribute Values":"null","entity_id":"14b0b7de-f59f-4955-9ab3-2367e347107d"}
# {"ID":"689.0","MakeText":"MERCEDES-BENZ","TypeName":"SLK 200 Kompressor","TypeNameFull":"MERCEDES-BENZ SLK 200 Kompressor","ModelText":"SLK 200","ModelTypeText":"SLK 200 Kompressor","Attribute Names":"Km","Attribute Values":"300","entity_id":"14fbcc73-7ab0-4938-b30e-db0639d51b58"}
# {"ID":"652.0","MakeText":"PORSCHE","TypeName":"911 Carrera Cabrio","TypeNameFull":"PORSCHE 911 Carrera Cabrio","ModelText":"911","ModelTypeText":"911 Carrera Cabrio","Attribute Names":"ConsumptionRatingText","Attribute Values":"null","entity_id":"150db244-da8e-4ae8-bae7-b546dd6949fb"}
# {"ID":"208.0","MakeText":"BMW","TypeName":"M3","TypeNameFull":"BMW M3","ModelText":"M3","ModelTypeText":"M3","Attribute Names":"ConditionTypeText","Attribute Values":"Occasion","entity_id":"154120af-ddb6-41f1-9d43-810107c29ff1"}
# {"ID":"3.0","MakeText":"AUDI","TypeName":"RS6 Avant quattro","TypeNameFull":"AUDI RS6 Avant quattro","ModelText":"RS6","ModelTypeText":"RS6 Avant quattro","Attribute Names":"InteriorColorText","Attribute Values":"beige","entity_id":"1543adb2-ff80-4ec0-93e5-c84063bf6eb5"}
# {"ID":"769.0","MakeText":"LAMBORGHINI","TypeName":"Diablo 5.7","TypeNameFull":"LAMBORGHINI Diablo 5.7","ModelText":"DIABLO","ModelTypeText":"Diablo 5.7","Attribute Names":"Properties","Attribute Values":"null","entity_id":"1549859c-b027-4f2d-8d16-69d5beddadd0"}
# {"ID":"731.0","MakeText":"MERCEDES-BENZ","TypeName":"SLS 63 AMG","TypeNameFull":"MERCEDES-BENZ SLS 63 AMG","ModelText":"SLS 63","ModelTypeText":"SLS 63 AMG","Attribute Names":"ConsumptionTotalText","Attribute Values":"13.2 l/100km","entity_id":"1595ad3a-80da-47ac-a345-41c3d247634a"}
# {"ID":"533.0","MakeText":"MERCEDES-BENZ","TypeName":"E 500 Avantgarde","TypeNameFull":"MERCEDES-BENZ E 500 Avantgarde","ModelText":"E 500","ModelTypeText":"E 500 Avantgarde","Attribute Names":"Doors","Attribute Values":"5","entity_id":"15c91949-2c23-4c23-a6df-d6c71aef7f79"}
# {"ID":"123.0","MakeText":"BMW-ALPINA","TypeName":"B7 TURBO","TypeNameFull":"BMW-ALPINA 5 SERIES B7 TURBO","ModelText":"5 SERIES","ModelTypeText":"5 SERIES B7 TURBO","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"1644ee75-612c-47b8-b878-cdf3f99dd742"}
# {"ID":"849.0","MakeText":"MERCEDES-BENZ","TypeName":"BLACK SERIES","TypeNameFull":"MERCEDES-BENZ SL 65 AMG BLACK SERIES","ModelText":"SL 65 AMG","ModelTypeText":"SL 65 AMG BLACK SERIES","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"1656febf-ef0a-4e50-b7b7-2ea82499b487"}
# {"ID":"373.0","MakeText":"SIMCA","TypeName":"Rallye2","TypeNameFull":"SIMCA Rallye2","ModelText":null,"ModelTypeText":"Rallye2","Attribute Names":"Hp","Attribute Values":"86","entity_id":"16b11cc1-af06-4a31-99b3-eea25fc5fc13"}
# {"ID":"190.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 600","TypeNameFull":"MERCEDES-BENZ SL 600","ModelText":"SL 600","ModelTypeText":"SL 600","Attribute Names":"FirstRegYear","Attribute Values":"2003","entity_id":"16b65378-c56d-4339-b35b-17101d3c5bdf"}
# {"ID":"647.0","MakeText":"PORSCHE","TypeName":"Cayenne Turbo","TypeNameFull":"PORSCHE Cayenne Turbo","ModelText":"CAYENNE","ModelTypeText":"Cayenne Turbo","Attribute Names":"DriveTypeText","Attribute Values":"Allrad","entity_id":"1711aa3c-de5d-4b06-a9eb-e3577a9e67f0"}
# {"ID":"1091.0","MakeText":"MERCEDES-BENZ","TypeName":"CL 600","TypeNameFull":"MERCEDES-BENZ CL 600","ModelText":"CL 600","ModelTypeText":"CL 600","Attribute Names":"Ccm","Attribute Values":"5786","entity_id":"172b6539-ee26-4b93-a18d-9fddc42b905c"}
# {"ID":"136.0","MakeText":"PORSCHE","TypeName":"911 Turbo","TypeNameFull":"PORSCHE 911 Turbo","ModelText":"911","ModelTypeText":"911 Turbo","Attribute Names":"BodyColorText","Attribute Values":"blau mét.","entity_id":"17487323-80b7-4bd5-86d9-2e6b352f20fc"}
# {"ID":"759.0","MakeText":"PORSCHE","TypeName":"GTR (GT3)","TypeNameFull":"PORSCHE 911 GTR (GT3)","ModelText":"911","ModelTypeText":"911 GTR (GT3)","Attribute Names":"Doors","Attribute Values":"2","entity_id":"17a1a8ed-5db9-4892-8357-d90738fc33d6"}
# {"ID":"77.0","MakeText":"PORSCHE","TypeName":"Panamera Turbo 4.8","TypeNameFull":"PORSCHE Panamera Turbo 4.8","ModelText":"PANAMERA","ModelTypeText":"Panamera Turbo 4.8","Attribute Names":"TransmissionTypeText","Attribute Values":"Automatisiertes Schaltgetriebe","entity_id":"17adf343-0511-4f46-ae19-fb688554ab69"}
# {"ID":"501.0","MakeText":"PORSCHE","TypeName":"911 Turbo S","TypeNameFull":"PORSCHE 911 Turbo S","ModelText":"911","ModelTypeText":"911 Turbo S","Attribute Names":"BodyTypeText","Attribute Values":"Coupé","entity_id":"17da37f2-e970-4fbd-b515-57cf96ce3530"}
# {"ID":"842.0","MakeText":"MERCEDES-BENZ","TypeName":"C 280 Elégance","TypeNameFull":"MERCEDES-BENZ C 280 Elégance","ModelText":"C 280","ModelTypeText":"C 280 Elégance","Attribute Names":"ConsumptionRatingText","Attribute Values":"G","entity_id":"17e886d2-8e8c-4db4-8961-b5ca490a8dd4"}
# {"ID":"70.0","MakeText":"OPEL","TypeName":"Speedster 2.2 16V","TypeNameFull":"OPEL Speedster 2.2 16V","ModelText":"SPEEDSTER","ModelTypeText":"Speedster 2.2 16V","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"1887bb6a-9881-45ce-af88-c7d4240fa477"}
# {"ID":"296.0","MakeText":"BENTLEY","TypeName":"Continental GTC 6.0","TypeNameFull":"BENTLEY Continental GTC 6.0","ModelText":"CONTINENTAL","ModelTypeText":"Continental GTC 6.0","Attribute Names":"BodyColorText","Attribute Values":"grau mét.","entity_id":"18a352be-699f-4aef-8166-57ce34ee04cb"}
# {"ID":"239.0","MakeText":"MAZDA","TypeName":"RX-7 2.6 Turbo II","TypeNameFull":"MAZDA RX-7 2.6 Turbo II","ModelText":"RX-7","ModelTypeText":"RX-7 2.6 Turbo II","Attribute Names":"BodyTypeText","Attribute Values":"Cabriolet","entity_id":"18c8b4dc-d33c-4bde-9126-58245d3ff3de"}
# {"ID":"959.0","MakeText":"PORSCHE","TypeName":"Panamera 4S 4.8","TypeNameFull":"PORSCHE Panamera 4S 4.8","ModelText":"PANAMERA","ModelTypeText":"Panamera 4S 4.8","Attribute Names":"Seats","Attribute Values":"4","entity_id":"18d3ba28-6a58-430c-852f-b2ed2888176c"}
# {"ID":"124.0","MakeText":"FERRARI","TypeName":"F360 Modena Berlinetta","TypeNameFull":"FERRARI F360 Modena Berlinetta","ModelText":"F360","ModelTypeText":"F360 Modena Berlinetta","Attribute Names":"ConsumptionTotalText","Attribute Values":"19.3 l/100km","entity_id":"18f349fa-5222-4579-a73e-7b4f920fb637"}
# {"ID":"930.0","MakeText":"BMW","TypeName":"M5","TypeNameFull":"BMW M5","ModelText":"M5","ModelTypeText":"M5","Attribute Names":"FirstRegMonth","Attribute Values":"6","entity_id":"19445b25-dbdb-43c5-b1e5-9afb6efd3fa5"}
# {"ID":"351.0","MakeText":"PORSCHE","TypeName":"911 Carrera 4","TypeNameFull":"PORSCHE 911 Carrera 4","ModelText":"911","ModelTypeText":"911 Carrera 4","Attribute Names":"DriveTypeText","Attribute Values":"Allrad","entity_id":"195d1f9d-18a9-4b8b-a243-07aa32f269b3"}
# {"ID":"265.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 600","TypeNameFull":"MERCEDES-BENZ SL 600","ModelText":"SL 600","ModelTypeText":"SL 600","Attribute Names":"ConsumptionRatingText","Attribute Values":"G","entity_id":"19973c39-37b5-4fe3-a729-31cff3d899f2"}
# {"ID":"307.0","MakeText":"FERRARI","TypeName":"612","TypeNameFull":"FERRARI 612","ModelText":"612","ModelTypeText":"612","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"19d3dfd2-ff32-46de-9709-d1a20b3d67cc"}
# {"ID":"740.0","MakeText":"MERCEDES-BENZ","TypeName":"CLK DTM AMG Cabriolet","TypeNameFull":"MERCEDES-BENZ CLK DTM AMG Cabriolet","ModelText":null,"ModelTypeText":"CLK DTM AMG Cabriolet","Attribute Names":"ConditionTypeText","Attribute Values":"Occasion","entity_id":"19e8f16e-91bd-411b-b364-c6e87bebb022"}
# {"ID":"706.0","MakeText":"FERRARI","TypeName":"575M","TypeNameFull":"FERRARI 575M","ModelText":"575M","ModelTypeText":"575M","Attribute Names":"FuelTypeText","Attribute Values":"Benzin","entity_id":"1a544382-76a3-4aa8-b08c-f9dd0986181d"}
# {"ID":"10.0","MakeText":"LAMBORGHINI","TypeName":"Espada GT 400 Serie 3","TypeNameFull":"LAMBORGHINI Espada GT 400 Serie 3","ModelText":null,"ModelTypeText":"Espada GT 400 Serie 3","Attribute Names":"ConsumptionTotalText","Attribute Values":"null","entity_id":"1a5cb6a9-3184-4127-94b0-1141bcf458ec"}
# {"ID":"687.0","MakeText":"LAMBORGHINI","TypeName":"GallardoLP570-4CpéTecnica","TypeNameFull":"LAMBORGHINI GallardoLP570-4CpéTecnica","ModelText":"GALLARDO","ModelTypeText":"GallardoLP570-4CpéTecnica","Attribute Names":"Co2EmissionText","Attribute Values":"319 g/km","entity_id":"1a9d1be8-e9db-4c66-bd6e-20137de2b784"}
# {"ID":"136.0","MakeText":"PORSCHE","TypeName":"911 Turbo","TypeNameFull":"PORSCHE 911 Turbo","ModelText":"911","ModelTypeText":"911 Turbo","Attribute Names":"FirstRegMonth","Attribute Values":"3","entity_id":"1b1535a9-c76e-4817-919e-9364b50fce23"}
# {"ID":"102.0","MakeText":"PORSCHE","TypeName":"911 Turbo Cabrio","TypeNameFull":"PORSCHE 911 Turbo Cabrio","ModelText":"911","ModelTypeText":"911 Turbo Cabrio","Attribute Names":"Hp","Attribute Values":"500","entity_id":"1b3cbaf0-6d58-420a-bb4d-cd7d8d02bd6f"}
# {"ID":"30.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 500","TypeNameFull":"MERCEDES-BENZ SL 500","ModelText":"SL 500","ModelTypeText":"SL 500","Attribute Names":"Doors","Attribute Values":"2","entity_id":"1b4c94de-67e0-4d6d-9d56-e3f3f350e9d1"}
# {"ID":"886.0","MakeText":"LAND ROVER","TypeName":"Range Rover 5.0 V8 SC","TypeNameFull":"LAND ROVER Range Rover 5.0 V8 SC","ModelText":"RANGE ROVER","ModelTypeText":"Range Rover 5.0 V8 SC","Attribute Names":"Doors","Attribute Values":"5","entity_id":"1b5c54af-6cb1-41a2-8ee9-1394dbb8ec0c"}
# {"ID":"236.0","MakeText":"RUF","TypeName":"CTR","TypeNameFull":"RUF CTR","ModelText":null,"ModelTypeText":"CTR","Attribute Names":"Hp","Attribute Values":"469","entity_id":"1b7d7031-01fa-4daf-877b-6d441598ce43"}
# {"ID":"1017.0","MakeText":"VW","TypeName":"Jetta 2.0 TDI Comfort","TypeNameFull":"VW Jetta 2.0 TDI Comfort","ModelText":"JETTA","ModelTypeText":"Jetta 2.0 TDI Comfort","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"1b8bbb2f-cb5b-4671-9409-d5dda0ac9d20"}
# {"ID":"337.0","MakeText":"BMW","TypeName":"740i","TypeNameFull":"BMW 740i","ModelText":"740","ModelTypeText":"740i","Attribute Names":"FuelTypeText","Attribute Values":"Benzin","entity_id":"1b9eaafc-e0f3-468a-a9a2-08aad6bfd1b9"}
# {"ID":"986.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 500","TypeNameFull":"MERCEDES-BENZ SL 500","ModelText":"SL 500","ModelTypeText":"SL 500","Attribute Names":"ConditionTypeText","Attribute Values":"Occasion","entity_id":"1ba4972b-a623-42df-9a43-caae70b75336"}
# {"ID":"640.0","MakeText":"BENTLEY","TypeName":"Continental GTC 6.0","TypeNameFull":"BENTLEY Continental GTC 6.0","ModelText":"CONTINENTAL","ModelTypeText":"Continental GTC 6.0","Attribute Names":"TransmissionTypeText","Attribute Values":"Automat","entity_id":"1bf69da3-8b38-48ca-bc4b-03448451fb52"}
# {"ID":"550.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 500","TypeNameFull":"MERCEDES-BENZ SL 500","ModelText":"SL 500","ModelTypeText":"SL 500","Attribute Names":"FirstRegMonth","Attribute Values":"2","entity_id":"1c268d7d-8f68-4a29-88e0-f51067563672"}
# {"ID":"770.0","MakeText":"AUDI","TypeName":"RS6 Avant quattro","TypeNameFull":"AUDI RS6 Avant quattro","ModelText":"RS6","ModelTypeText":"RS6 Avant quattro","Attribute Names":"DriveTypeText","Attribute Values":"Allrad","entity_id":"1c319191-7a8b-475d-94d9-af4cd4078e77"}
# {"ID":"387.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 63 AMG","TypeNameFull":"MERCEDES-BENZ SL 63 AMG","ModelText":"SL 63 AMG","ModelTypeText":"SL 63 AMG","Attribute Names":"ConsumptionRatingText","Attribute Values":"null","entity_id":"1d042a0f-4300-4bd4-852f-65ee7be5c63b"}
# {"ID":"23.0","MakeText":"PORSCHE","TypeName":"Cayenne Turbo","TypeNameFull":"PORSCHE Cayenne Turbo","ModelText":"CAYENNE","ModelTypeText":"Cayenne Turbo","Attribute Names":"BodyColorText","Attribute Values":"anthrazit mét.","entity_id":"1d305fb9-ce85-4573-8484-3cedd6d9f42f"}
# {"ID":"928.0","MakeText":"AUDI","TypeName":"RS6 Avant quattro","TypeNameFull":"AUDI RS6 Avant quattro","ModelText":"RS6","ModelTypeText":"RS6 Avant quattro","Attribute Names":"FirstRegYear","Attribute Values":"2003","entity_id":"1d42f36f-1a25-42b4-8013-e7363effff64"}
# {"ID":"259.0","MakeText":"LANCIA","TypeName":"Delta HF Integrale Evo","TypeNameFull":"LANCIA Delta HF Integrale Evo","ModelText":"DELTA","ModelTypeText":"Delta HF Integrale Evo","Attribute Names":"TransmissionTypeText","Attribute Values":"Schaltgetriebe manuell","entity_id":"1d6bb67b-6950-4486-8b83-62de5b361efb"}
# {"ID":"634.0","MakeText":"TOYOTA","TypeName":"Celica 2800 i Supra","TypeNameFull":"TOYOTA Celica 2800 i Supra","ModelText":"CELICA","ModelTypeText":"Celica 2800 i Supra","Attribute Names":"Seats","Attribute Values":"5","entity_id":"1d928d9c-59f4-4156-b9e4-3be54e865bad"}
# {"ID":"247.0","MakeText":"JAGUAR","TypeName":"S-Type 4.2 V8 S/C R","TypeNameFull":"JAGUAR S-Type 4.2 V8 S/C R","ModelText":"S-TYPE","ModelTypeText":"S-Type 4.2 V8 S/C R","Attribute Names":"TransmissionTypeText","Attribute Values":"Automat","entity_id":"1dea6662-624d-44b1-ba0c-c55c338ee893"}
# {"ID":"682.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 55 AMG","TypeNameFull":"MERCEDES-BENZ SL 55 AMG","ModelText":"SL 55 AMG","ModelTypeText":"SL 55 AMG","Attribute Names":"Co2EmissionText","Attribute Values":"340 g/km","entity_id":"1df4c223-5a04-4a0a-8c4a-15c1172588bf"}
# {"ID":"104.0","MakeText":"AUDI","TypeName":"RS4 Avant quattro","TypeNameFull":"AUDI RS4 Avant quattro","ModelText":"RS4","ModelTypeText":"RS4 Avant quattro","Attribute Names":"FirstRegYear","Attribute Values":"2001","entity_id":"1e023213-f11c-438c-8d1f-9b77384368c7"}
# {"ID":"799.0","MakeText":"MERCEDES-BENZ","TypeName":"S 500 L","TypeNameFull":"MERCEDES-BENZ S 500 L","ModelText":"S 500","ModelTypeText":"S 500 L","Attribute Names":"BodyColorText","Attribute Values":"schwarz mét.","entity_id":"1e0339b7-0556-4081-8d36-a5fc67c181fa"}
# {"ID":"295.0","MakeText":"MERCEDES-BENZ","TypeName":"CLK 63 AMG Black Series","TypeNameFull":"MERCEDES-BENZ CLK 63 AMG Black Series","ModelText":"CLK 63 AMG","ModelTypeText":"CLK 63 AMG Black Series","Attribute Names":"FirstRegYear","Attribute Values":"2008","entity_id":"1e1ec3b9-4970-4b6b-bde4-289b59b07112"}
# {"ID":"143.0","MakeText":"MERCEDES-BENZ","TypeName":"S 65 AMG L","TypeNameFull":"MERCEDES-BENZ S 65 AMG L","ModelText":"S 65 AMG","ModelTypeText":"S 65 AMG L","Attribute Names":"ConditionTypeText","Attribute Values":"Occasion","entity_id":"1e3e4407-18b3-447c-adee-5ef9cb266921"}
# {"ID":"843.0","MakeText":"AUDI","TypeName":"RS6 Avant quattro","TypeNameFull":"AUDI RS6 Avant quattro","ModelText":"RS6","ModelTypeText":"RS6 Avant quattro","Attribute Names":"DriveTypeText","Attribute Values":"Allrad","entity_id":"1e550591-f78d-4483-af05-0fff374b8243"}
# {"ID":"1099.0","MakeText":"CHEVROLET","TypeName":"C1","TypeNameFull":"CHEVROLET CORVETTE C1","ModelText":"CORVETTE","ModelTypeText":"CORVETTE C1","Attribute Names":"BodyColorText","Attribute Values":"weiss","entity_id":"1e59878d-9ce6-42e2-888f-5d8f7e859e4a"}
# {"ID":"692.0","MakeText":"MERCEDES-BENZ","TypeName":"SLK 55 AMG","TypeNameFull":"MERCEDES-BENZ SLK 55 AMG","ModelText":"SLK 55 AMG","ModelTypeText":"SLK 55 AMG","Attribute Names":"ConsumptionTotalText","Attribute Values":"8.4 l/100km","entity_id":"1e8164b6-2189-4e31-9e7a-178754885cd0"}
# {"ID":"356.0","MakeText":"PORSCHE","TypeName":"911 GT2","TypeNameFull":"PORSCHE 911 GT2","ModelText":"911","ModelTypeText":"911 GT2","Attribute Names":"ConsumptionRatingText","Attribute Values":"G","entity_id":"1ee78fea-6047-4773-b515-3e9c89c1fcbe"}
# {"ID":"496.0","MakeText":"DODGE","TypeName":"B 200","TypeNameFull":"DODGE B 200","ModelText":null,"ModelTypeText":"B 200","Attribute Names":"TransmissionTypeText","Attribute Values":"Automat","entity_id":"1f04a1b2-5edb-41d7-a22b-a223095551af"}
# {"ID":"580.0","MakeText":"MERCEDES-BENZ","TypeName":"CL 600","TypeNameFull":"MERCEDES-BENZ CL 600","ModelText":"CL 600","ModelTypeText":"CL 600","Attribute Names":"Km","Attribute Values":"103800","entity_id":"1f40c078-727f-4b3e-9684-10cd332c5273"}
# ...
# {"ID":"164.0","MakeText":"MERCEDES-BENZ","TypeName":"E 55 AMG Avantgarde","TypeNameFull":"MERCEDES-BENZ E 55 AMG Avantgarde","ModelText":"E 55 AMG","ModelTypeText":"E 55 AMG Avantgarde","Attribute Names":"ConsumptionRatingText","Attribute Values":"null","entity_id":"bfcd48db-95ab-41e7-aa68-0724ff88fd96"}
# {"ID":"38.0","MakeText":"PORSCHE","TypeName":"Cayenne Turbo","TypeNameFull":"PORSCHE Cayenne Turbo","ModelText":"CAYENNE","ModelTypeText":"Cayenne Turbo","Attribute Names":"TransmissionTypeText","Attribute Values":"Automat sequentiell","entity_id":"bfded356-f3dd-4d2c-9fd5-99295f0f3def"}
# {"ID":"529.0","MakeText":"LAMBORGHINI","TypeName":"Murciélago 6.2 Coupé","TypeNameFull":"LAMBORGHINI Murciélago 6.2 Coupé","ModelText":"MURCIÉLAGO","ModelTypeText":"Murciélago 6.2 Coupé","Attribute Names":"ConditionTypeText","Attribute Values":"Occasion","entity_id":"bffdb4c3-2ff0-454e-839f-5106dcec93ce"}
# {"ID":"879.0","MakeText":"VW","TypeName":"Golf R32 4Motion","TypeNameFull":"VW Golf R32 4Motion","ModelText":"GOLF","ModelTypeText":"Golf R32 4Motion","Attribute Names":"TransmissionTypeText","Attribute Values":"Automatisiertes Schaltgetriebe","entity_id":"c00cb862-50ec-4660-9937-3811c467ae65"}
# {"ID":"595.0","MakeText":"ASTON MARTIN","TypeName":"V8 Vantage 4.3","TypeNameFull":"ASTON MARTIN V8 Vantage 4.3","ModelText":"V8 Vantage","ModelTypeText":"V8 Vantage 4.3","Attribute Names":"InteriorColorText","Attribute Values":"schwarz","entity_id":"c0395bda-340d-493d-9408-44092d9b8da1"}
# {"ID":"706.0","MakeText":"FERRARI","TypeName":"575M","TypeNameFull":"FERRARI 575M","ModelText":"575M","ModelTypeText":"575M","Attribute Names":"BodyColorText","Attribute Values":"schwarz mét.","entity_id":"c06ddd84-5484-4805-a597-e38eab7be303"}
# {"ID":"47.0","MakeText":"BMW","TypeName":"330Ci","TypeNameFull":"BMW 330Ci","ModelText":"330","ModelTypeText":"330Ci","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"c07444e3-151c-4db8-9ca7-633142ad1fbd"}
# {"ID":"888.0","MakeText":"MG","TypeName":"M Roadster","TypeNameFull":"MG M Roadster","ModelText":null,"ModelTypeText":"M Roadster","Attribute Names":"Seats","Attribute Values":"2","entity_id":"c0a347d4-cae3-4561-b749-0ba8dbfccc54"}
# {"ID":"886.0","MakeText":"LAND ROVER","TypeName":"Range Rover 5.0 V8 SC","TypeNameFull":"LAND ROVER Range Rover 5.0 V8 SC","ModelText":"RANGE ROVER","ModelTypeText":"Range Rover 5.0 V8 SC","Attribute Names":"Km","Attribute Values":"9000","entity_id":"c1463a2c-9062-4175-9205-f22336a5b4e1"}
# {"ID":"955.0","MakeText":"MERCEDES-BENZ","TypeName":"E 320 CDI Avantgarde","TypeNameFull":"MERCEDES-BENZ E 320 CDI Avantgarde","ModelText":"E 320","ModelTypeText":"E 320 CDI Avantgarde","Attribute Names":"Km","Attribute Values":"100","entity_id":"c15da2f3-ac0f-4838-a655-e9214cc5d6db"}
# {"ID":"120.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 600","TypeNameFull":"MERCEDES-BENZ SL 600","ModelText":"SL 600","ModelTypeText":"SL 600","Attribute Names":"FirstRegYear","Attribute Values":"2004","entity_id":"c17c7110-8e8f-4a41-a857-4bf312ae9ca9"}
# {"ID":"572.0","MakeText":"BMW","TypeName":"760i L","TypeNameFull":"BMW 760i L","ModelText":"760","ModelTypeText":"760i L","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"c1c4a279-1dac-4f5f-a2fb-1e3dabeb055e"}
# {"ID":"1030.0","MakeText":"MERCEDES-BENZ","TypeName":"E 55 AMG Avantgarde","TypeNameFull":"MERCEDES-BENZ E 55 AMG Avantgarde","ModelText":"E 55 AMG","ModelTypeText":"E 55 AMG Avantgarde","Attribute Names":"Doors","Attribute Values":"4","entity_id":"c1e6e7d0-88fa-4b40-827f-428aff16ee7c"}
# {"ID":"39.0","MakeText":"MERCEDES-BENZ","TypeName":"S 65 L / BRABUS T65 S","TypeNameFull":"MERCEDES-BENZ S 65 L / BRABUS T65 S","ModelText":"S 65 AMG","ModelTypeText":"S 65 L / BRABUS T65 S","Attribute Names":"BodyColorText","Attribute Values":"beige","entity_id":"c20096da-7757-4c92-b12e-08e392fe2684"}
# {"ID":"494.0","MakeText":"AUDI","TypeName":"A8 4.2 quattro","TypeNameFull":"AUDI A8 4.2 quattro","ModelText":"A8","ModelTypeText":"A8 4.2 quattro","Attribute Names":"City","Attribute Values":"Zuzwil","entity_id":"c20f640b-355a-45ba-b34d-bf1bbf645bcd"}
# {"ID":"525.0","MakeText":"BMW","TypeName":"M5","TypeNameFull":"BMW M5","ModelText":"M5","ModelTypeText":"M5","Attribute Names":"DriveTypeText","Attribute Values":"Hinterradantrieb","entity_id":"c22293a8-2694-4088-ac5c-c93369c29c7c"}
# {"ID":"351.0","MakeText":"PORSCHE","TypeName":"911 Carrera 4","TypeNameFull":"PORSCHE 911 Carrera 4","ModelText":"911","ModelTypeText":"911 Carrera 4","Attribute Names":"Doors","Attribute Values":"2","entity_id":"c23e68b3-8997-4f00-9b14-b79ec74d7a78"}
# {"ID":"500.0","MakeText":"JAGUAR","TypeName":"S-Type 4.0 V8","TypeNameFull":"JAGUAR S-Type 4.0 V8","ModelText":"S-TYPE","ModelTypeText":"S-Type 4.0 V8","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"c2df25bf-100a-4645-a9ff-5dbef5008e7a"}
# {"ID":"888.0","MakeText":"MG","TypeName":"M Roadster","TypeNameFull":"MG M Roadster","ModelText":null,"ModelTypeText":"M Roadster","Attribute Names":"ConditionTypeText","Attribute Values":"Oldtimer","entity_id":"c2fd7d30-35f0-4f59-af68-7da84c630aff"}
# {"ID":"820.0","MakeText":"PORSCHE","TypeName":"911 Carrera 4","TypeNameFull":"PORSCHE 911 Carrera 4","ModelText":"911","ModelTypeText":"911 Carrera 4","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"c3182cfc-c1a3-44ef-8957-45867e97aae2"}
# {"ID":"607.0","MakeText":"MERCEDES-BENZ","TypeName":"SLK 230 Kompressor","TypeNameFull":"MERCEDES-BENZ SLK 230 Kompressor","ModelText":"SLK 230","ModelTypeText":"SLK 230 Kompressor","Attribute Names":"Ccm","Attribute Values":"2295","entity_id":"c3307349-d2f9-4759-8dca-84aee629c05a"}
# {"ID":"790.0","MakeText":"MERCEDES-BENZ","TypeName":"S 320","TypeNameFull":"MERCEDES-BENZ S 320","ModelText":"S 320","ModelTypeText":"S 320","Attribute Names":"Doors","Attribute Values":"4","entity_id":"c343b393-740b-4c2c-bf4a-45c1d05f010d"}
# {"ID":"1019.0","MakeText":"WIESMANN","TypeName":"GT MF5","TypeNameFull":"WIESMANN GT MF5","ModelText":"COUPE","ModelTypeText":"GT MF5","Attribute Names":"FirstRegYear","Attribute Values":"2008","entity_id":"c3565e11-527e-44cf-9980-65c7cb2fc8f5"}
# {"ID":"116.0","MakeText":"AUDI","TypeName":"RS6 Avant 5.0 V10 quattro","TypeNameFull":"AUDI RS6 Avant 5.0 V10 quattro","ModelText":"RS6","ModelTypeText":"RS6 Avant 5.0 V10 quattro","Attribute Names":"DriveTypeText","Attribute Values":"Allrad","entity_id":"c3ad2125-87ef-4b63-aa56-acd84ecca116"}
# {"ID":"198.0","MakeText":"MERCEDES-BENZ","TypeName":"170V B Cabrio 136","TypeNameFull":"MERCEDES-BENZ 170V B Cabrio 136","ModelText":null,"ModelTypeText":"170V B Cabrio 136","Attribute Names":"FuelTypeText","Attribute Values":"Benzin","entity_id":"c3f53438-45c0-4b8b-86ef-d47e5eea9978"}
# {"ID":"194.0","MakeText":"PORSCHE","TypeName":"911 Carrera 4S","TypeNameFull":"PORSCHE 911 Carrera 4S","ModelText":"911","ModelTypeText":"911 Carrera 4S","Attribute Names":"TransmissionTypeText","Attribute Values":"Schaltgetriebe manuell","entity_id":"c3f53cca-d968-48ef-bb52-1a80d4bfbe75"}
# {"ID":"1069.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 500","TypeNameFull":"MERCEDES-BENZ SL 500","ModelText":"SL 500","ModelTypeText":"SL 500","Attribute Names":"FirstRegMonth","Attribute Values":"1","entity_id":"c3fa1120-506a-41a2-8361-a8e4129e434b"}
# {"ID":"1110.0","MakeText":"CHEVROLET","TypeName":"2500HD 6.6l V8","TypeNameFull":"CHEVROLET Silverado 2500HD 6.6l V8","ModelText":"Silverado","ModelTypeText":"Silverado 2500HD 6.6l V8","Attribute Names":"BodyTypeText","Attribute Values":"Pick-up","entity_id":"c449f0cb-9eda-4fc7-951a-902d31e14a83"}
# {"ID":"937.0","MakeText":"BMW","TypeName":"M3","TypeNameFull":"BMW M3","ModelText":"M3","ModelTypeText":"M3","Attribute Names":"ConditionTypeText","Attribute Values":"Occasion","entity_id":"c48bfaaa-9c8d-41ab-a72c-105fcd89320c"}
# {"ID":"759.0","MakeText":"PORSCHE","TypeName":"GTR (GT3)","TypeNameFull":"PORSCHE 911 GTR (GT3)","ModelText":"911","ModelTypeText":"911 GTR (GT3)","Attribute Names":"ConsumptionTotalText","Attribute Values":"null","entity_id":"c49a5c6e-467a-441f-aa23-ec6dd69cbe02"}
# {"ID":"651.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 600","TypeNameFull":"MERCEDES-BENZ SL 600","ModelText":"SL 600","ModelTypeText":"SL 600","Attribute Names":"BodyTypeText","Attribute Values":"Cabriolet","entity_id":"c4b8c1c6-e09d-4eb3-b491-06b7e5d78825"}
# {"ID":"727.0","MakeText":"BMW","TypeName":"550i Touring","TypeNameFull":"BMW 550i Touring","ModelText":"550","ModelTypeText":"550i Touring","Attribute Names":"ConsumptionRatingText","Attribute Values":"G","entity_id":"c4f00372-2ea5-4382-96c5-104e717fae24"}
# {"ID":"523.0","MakeText":"FERRARI","TypeName":"F355 Spider","TypeNameFull":"FERRARI F355 Spider","ModelText":"F355","ModelTypeText":"F355 Spider","Attribute Names":"ConsumptionRatingText","Attribute Values":"null","entity_id":"c4f1a82a-4fd4-4a89-8b04-d6bdfd719cc8"}
# {"ID":"168.0","MakeText":"SUBARU","TypeName":"Impreza 2.5T WRX","TypeNameFull":"SUBARU Impreza 2.5T WRX","ModelText":"IMPREZA","ModelTypeText":"Impreza 2.5T WRX","Attribute Names":"Seats","Attribute Values":"5","entity_id":"c501b467-cb47-488a-a5ac-6d758411db93"}
# {"ID":"643.0","MakeText":"BMW","TypeName":"330Ci","TypeNameFull":"BMW 330Ci","ModelText":"330","ModelTypeText":"330Ci","Attribute Names":"InteriorColorText","Attribute Values":"grau","entity_id":"c53337a5-15c3-4d30-b863-d2fc2c0ef055"}
# {"ID":"1029.0","MakeText":"BENTLEY","TypeName":"Arnage T","TypeNameFull":"BENTLEY Arnage T","ModelText":"ARNAGE","ModelTypeText":"Arnage T","Attribute Names":"Ccm","Attribute Values":"6761","entity_id":"c55238a9-873b-482d-8881-c81763e31c08"}
# {"ID":"609.0","MakeText":"PORSCHE","TypeName":"911 Carrera Cabrio","TypeNameFull":"PORSCHE 911 Carrera Cabrio","ModelText":"911","ModelTypeText":"911 Carrera Cabrio","Attribute Names":"FirstRegYear","Attribute Values":"1996","entity_id":"c569c75a-1a86-4c71-8b8a-1bce457d235a"}
# {"ID":"804.0","MakeText":"MERCEDES-BENZ","TypeName":"S 320","TypeNameFull":"MERCEDES-BENZ S 320","ModelText":"S 320","ModelTypeText":"S 320","Attribute Names":"ConsumptionTotalText","Attribute Values":"13.4 l/100km","entity_id":"c590eb7b-87a5-47dc-8b42-508180014208"}
# {"ID":"800.0","MakeText":"BMW","TypeName":"525i","TypeNameFull":"BMW 525i","ModelText":"525","ModelTypeText":"525i","Attribute Names":"InteriorColorText","Attribute Values":"beige","entity_id":"c59ac9fd-10e7-442b-84ba-038eb6bdb0c8"}
# {"ID":"237.0","MakeText":"RENAULT","TypeName":"R5 Turbo 2","TypeNameFull":"RENAULT R5 Turbo 2","ModelText":"R5","ModelTypeText":"R5 Turbo 2","Attribute Names":"City","Attribute Values":"Zuzwil","entity_id":"c66b9f03-26ec-4908-bf52-11c96200258e"}
# {"ID":"723.0","MakeText":"FERRARI","TypeName":"Challenge GT3 LOOK","TypeNameFull":"FERRARI F430 Challenge GT3 LOOK","ModelText":"F430","ModelTypeText":"F430 Challenge GT3 LOOK","Attribute Names":"ConsumptionRatingText","Attribute Values":"null","entity_id":"c6bbaeae-2ab7-4793-9fbb-389d9228870f"}
# {"ID":"42.0","MakeText":"BMW","TypeName":"X5 4.4i","TypeNameFull":"BMW X5 4.4i","ModelText":"X5","ModelTypeText":"X5 4.4i","Attribute Names":"Km","Attribute Values":"40500","entity_id":"c6bdaaa0-f9d3-4688-a17b-5d5e16587a67"}
# {"ID":"764.0","MakeText":"PORSCHE","TypeName":"911 Carrera 4 S Cabrio","TypeNameFull":"PORSCHE 911 Carrera 4 S Cabrio","ModelText":"911","ModelTypeText":"911 Carrera 4 S Cabrio","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"c70b6ad6-3133-45a2-a406-4729b5b78bb3"}
# {"ID":"728.0","MakeText":"BENTLEY","TypeName":"Arnage Red Label","TypeNameFull":"BENTLEY Arnage Red Label","ModelText":"ARNAGE","ModelTypeText":"Arnage Red Label","Attribute Names":"Hp","Attribute Values":"405","entity_id":"c76e09e9-1db1-42ab-94be-eadb27c992ca"}
# {"ID":"717.0","MakeText":"MATRA","TypeName":"SIMCA Bagheera Serie II","TypeNameFull":"MATRA SIMCA Bagheera Serie II","ModelText":null,"ModelTypeText":"SIMCA Bagheera Serie II","Attribute Names":"DriveTypeText","Attribute Values":"Hinterradantrieb","entity_id":"c78641c5-c550-4a8c-8515-bd1b713a16d4"}
# {"ID":"1137.0","MakeText":"RENAULT","TypeName":"Espace 2.0 T Privilège","TypeNameFull":"RENAULT Espace 2.0 T Privilège","ModelText":"ESPACE","ModelTypeText":"Espace 2.0 T Privilège","Attribute Names":"FuelTypeText","Attribute Values":"Benzin","entity_id":"c7aedee0-bed7-48a6-b889-0023a899df0a"}
# {"ID":"604.0","MakeText":"MERCEDES-BENZ","TypeName":"SEL 3.5","TypeNameFull":"MERCEDES-BENZ 300 SEL 3.5","ModelText":"300","ModelTypeText":"300 SEL 3.5","Attribute Names":"TransmissionTypeText","Attribute Values":"Automatik-Getriebe","entity_id":"c7ba68b3-792f-40af-91a7-b9977eb4e8cc"}
# {"ID":"1013.0","MakeText":"MERCEDES-BENZ","TypeName":"300SL Roadster","TypeNameFull":"MERCEDES-BENZ 300SL Roadster","ModelText":null,"ModelTypeText":"300SL Roadster","Attribute Names":"ConsumptionTotalText","Attribute Values":"null","entity_id":"c7cb8ce1-6427-4cae-97a2-4e931f96bdcd"}
# {"ID":"268.0","MakeText":"RUF","TypeName":"CTR 2 Sport","TypeNameFull":"RUF CTR 2 Sport","ModelText":null,"ModelTypeText":"CTR 2 Sport","Attribute Names":"ConsumptionTotalText","Attribute Values":"null","entity_id":"c83069fd-10d8-40d5-be99-d38177980e49"}
# {"ID":"423.0","MakeText":"MERCEDES-BENZ","TypeName":"SL 55 AMG","TypeNameFull":"MERCEDES-BENZ SL 55 AMG","ModelText":"SL 55 AMG","ModelTypeText":"SL 55 AMG","Attribute Names":"ConditionTypeText","Attribute Values":"Occasion","entity_id":"c8565515-43cc-4ce2-afbf-205d368f23f4"}
# {"ID":"192.0","MakeText":"MERCEDES-BENZ","TypeName":"CLK 55 AMG Avantgarde","TypeNameFull":"MERCEDES-BENZ CLK 55 AMG Avantgarde","ModelText":"CLK 55 AMG","ModelTypeText":"CLK 55 AMG Avantgarde","Attribute Names":"Ccm","Attribute Values":"5439","entity_id":"c8743771-d012-4b0b-afd0-99e97d0f1e3a"}
# {"ID":"119.0","MakeText":"PORSCHE","TypeName":"911 Turbo","TypeNameFull":"PORSCHE 911 Turbo","ModelText":"911","ModelTypeText":"911 Turbo","Attribute Names":"InteriorColorText","Attribute Values":"beige","entity_id":"c8bac130-ecbe-4f8c-b378-07dde8aef73f"}
# {"ID":"122.0","MakeText":"MERCEDES-BENZ","TypeName":"C 320 Elégance","TypeNameFull":"MERCEDES-BENZ C 320 Elégance","ModelText":"C 320","ModelTypeText":"C 320 Elégance","Attribute Names":"FuelTypeText","Attribute Values":"Benzin","entity_id":"c95498db-5c28-4add-8f67-17ffc0291f44"}
# {"ID":"481.0","MakeText":"JAGUAR","TypeName":"XJR 4.0 V8 S/C","TypeNameFull":"JAGUAR XJR 4.0 V8 S/C","ModelText":"XJ","ModelTypeText":"XJR 4.0 V8 S/C","Attribute Names":"TransmissionTypeText","Attribute Values":"Automat","entity_id":"c9d15bbd-d18f-4e69-992b-59da028b908d"}
# {"ID":"169.0","MakeText":"ASTON MARTIN","TypeName":"DB7","TypeNameFull":"ASTON MARTIN DB7","ModelText":"DB7","ModelTypeText":"DB7","Attribute Names":"City","Attribute Values":"Zuzwil","entity_id":"ca0cc4b4-ae9f-4086-81e1-8dca3fa1b75f"}
# {"ID":"168.0","MakeText":"SUBARU","TypeName":"Impreza 2.5T WRX","TypeNameFull":"SUBARU Impreza 2.5T WRX","ModelText":"IMPREZA","ModelTypeText":"Impreza 2.5T WRX","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\"","entity_id":"ca14c1ee-66a3-498b-b361-de0259da6e80"}
# {"ID":"539.0","MakeText":"ROLLS-ROYCE","TypeName":"II Coupé","TypeNameFull":"ROLLS-ROYCE CORNICHE II Coupé","ModelText":"CORNICHE","ModelTypeText":"CORNICHE II Coupé","Attribute Names":"Seats","Attribute Values":"4","entity_id":"ca2d10db-6317-4aba-a2d4-56660bac693a"}
# {"ID":"930.0","MakeText":"BMW","TypeName":"M5","TypeNameFull":"BMW M5","ModelText":"M5","ModelTypeText":"M5","Attribute Names":"Properties","Attribute Values":"\"Ab MFK\", \"Tuning\"","entity_id":"ca92583e-e03e-490c-b29f-fe1084c83b47"}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Task 1:Data preprocessing

# %% [markdown]
#  - Objective -
#  Transform the supplier data to achieve the same granularity as the target data.
#  - The json file is simply written in excel with no changes made
#  - Modules: xlsxwriter,xlrd,xlwt,xlutils and xl_copy

# %%
import json
import xlsxwriter
import xlrd, xlwt
from xlutils.copy import copy as xl_copy

## Used for Normalizing color values
ColorMapping = {"gold":"gold","grn":"green", "schwarz":"black", "rot":"red", "silber":"silver", "anthrazit":"anthracite","weiss":"white","blau":"blue","grau":"grey","gelb":"yellow","violett":"voilet","grn":"green","orange":"orange","beige":"beige","bordeaux":"bordeaux","braun":"brown"}

## Used for Normalizing DriverType values
DriverTypeMapping= {"Allrad":"1","Hinterradantrieb":"2","Vorderradantrieb":"3","null":"0"}

## Target schema and its default value
TargetSchemaMap = {"carType":"NewSupplier","color":"Unknown","condition":"NewSupplier","currency":"NewSupplier","drive":"NewSupplier","city":"Unknown","country":"NewSupplier","make":"NewSupplier","manufacture_year":"NewSupplier","mileage":"NewSupplier","mileage_unit":"NewSupplier","model":"NewSupplier","model_variant":"NewSupplier","price_on_request":"NewSupplier","type":"NewSupplier","zip":"NewSupplier","manufacture_month":"NewSupplier","fuel_consumption_unit":"NewSupplier"}

## Utilify functions
def stripNonAlphaNum(text):
    import re
    list = re.compile(r'\W+').split(text)
    stripped_string = re.sub(r'\W+', '', list[0])
    alphanumeric = ""

    for character in stripped_string:
        if ord(character) >= 65 and ord(character) <= 90:
             alphanumeric += character
            ## checking for lower case
        elif ord(character) >= 97 and ord(character) <= 122:
             alphanumeric += character
    return alphanumeric.lower()

def mynormalize(dataType, text):
    if dataType=="color":
        germanColor = stripNonAlphaNum(text)
        return ColorMapping[germanColor]
    elif dataType=="drive":
        return  DriverTypeMapping[text]
    elif dataType=="milage":
        return  text.split(" ")[0]

## Final output in MasterExcel.xlsx
workbook = xlsxwriter.Workbook('MasterExcel.xlsx')

### Add 1st Tab/Sheet now
worksheet = workbook.add_worksheet()
row = 0
col = 0
row+=1
file1 = open('supplier_car.json', 'r')
Lines = file1.readlines()
headingAdded = False
for line in Lines:
    r = line.strip()
    rowData = json.loads(r)
    if headingAdded == False:
        for keyInSuppliersData in rowData:
            worksheet.write(row, col,keyInSuppliersData)
            col+=1
            headingAdded = True
        row+=1
    col=0
    for keyInSuppliersData in rowData:
        #print("key is {} and its valye is {}".format(keyInSuppliersData, rowData[keyInSuppliersData]))
        worksheet.write(row, col,rowData[keyInSuppliersData])
        col+=1
    row+=1

### Add 2nd Tab/Sheet now

worksheet2 = workbook.add_worksheet()
row = 0
col = 0
row+=1
headingAdded = False
for line in Lines:
    r = line.strip()
    rowData = json.loads(r)
    if headingAdded == False:
        for keyInSuppliersData in rowData:
            worksheet2.write(row, col,keyInSuppliersData)
            col+=1
            headingAdded = True
        row+=1
    col=0
    for keyInSuppliersData in rowData:
        if keyInSuppliersData == "Attribute Names" and rowData[keyInSuppliersData] == "BodyColorText":
            #print("in normalize")
            worksheet2.write(row, col,rowData[keyInSuppliersData])
            col+=1
            suppliedBodyColr =  mynormalize("color", rowData["Attribute Values"])
            #print("val is {}".format(suppliedBodyColr))
            worksheet2.write(row, col,suppliedBodyColr)
            col+=1
        elif keyInSuppliersData == "Attribute Values" and rowData["Attribute Names"] == "BodyColorText":
            #print("skipped")
            continue
        elif keyInSuppliersData == "Attribute Names" and rowData[keyInSuppliersData] == "DriveTypeText":
            worksheet2.write(row, col,rowData[keyInSuppliersData])
            col+=1
            normalizedDriverType = mynormalize("drive", rowData["Attribute Values"])
            worksheet2.write(row, col, normalizedDriverType)
            col+=1
        elif keyInSuppliersData == "Attribute Values" and rowData["Attribute Names"] == "DriveTypeText":
            #print("skipped")
            continue
        elif keyInSuppliersData == "Attribute Names" and rowData[keyInSuppliersData] == "ConsumptionTotalText":
            worksheet2.write(row, col,rowData[keyInSuppliersData])
            col+=1
            normalizedMilage = mynormalize("milage", rowData["Attribute Values"])
            worksheet2.write(row, col, normalizedMilage)
            col+=1
        elif keyInSuppliersData == "Attribute Values" and rowData["Attribute Names"] == "ConsumptionTotalText":
            #print("skipped")
            continue
        else:
            worksheet2.write(row, col,rowData[keyInSuppliersData])
            col+=1
    row+=1

### Add 3rd Tab/Sheet now

worksheet3 = workbook.add_worksheet()
row = 0
col = 0

# Add the Target schema header into excel
for keyInTargetschema in TargetSchemaMap:
    worksheet3.write(row, col, keyInTargetschema)
    col+=1

row+=1
col=0
for line in Lines:
    r = line.strip()
    rowData = json.loads(r)
    
    # populate local object with only required values (like color, city, make, model and model_variant) from rowData (i.e. supplier data)
    localRetrievedData = {}
    for keyInSuppliersData in rowData:
        #print("key is {} and its value is {}".format(keyInSuppliersData, rowData[keyInSuppliersData]))        
        if keyInSuppliersData == "Attribute Names" and rowData[keyInSuppliersData] == "BodyColorText":
            localRetrievedData["color"]=mynormalize("color", rowData["Attribute Values"])
        if keyInSuppliersData == "Attribute Names" and rowData[keyInSuppliersData] == "ConsumptionTotalText":
            localRetrievedData["mileage"]=mynormalize("milage", rowData["Attribute Values"])
        elif keyInSuppliersData == "Attribute Names" and rowData[keyInSuppliersData] == "City":
            localRetrievedData["city"]=rowData["Attribute Values"]
        elif keyInSuppliersData == "MakeText":
            localRetrievedData["make"]=rowData[keyInSuppliersData]
        elif keyInSuppliersData == "ModelText":
            localRetrievedData["model"]=rowData[keyInSuppliersData]
        elif keyInSuppliersData == "ModelTypeText":
            localRetrievedData["model_variant"]=rowData[keyInSuppliersData]

    # Now fill the worsheet with values localRetrievedData, if exists. Else add default values defined in TargetSchemaMap.
    col=0
    for keyInTargetschema in TargetSchemaMap:
        if keyInTargetschema in localRetrievedData:
            worksheet3.write(row, col,localRetrievedData[keyInTargetschema])
        else:
            worksheet3.write(row, col,TargetSchemaMap[keyInTargetschema])     
        col+=1

    row+=1

## close the workbook. This is the end.
workbook.close()

# %% [markdown]
# - Output:The .json is parsed and each lines are read and entries are put in the Excel sheet "MasterExcel.xlsx
#  - This MasterExcel can then be used to have a sneakpeak of every details of matrix and one can apply various filtering techniques.
#  - The .xlsx file is read using pandas to give a snapshot of the view of supplier data.

# %%
import pandas as pd
xls = pd.ExcelFile('MasterExcel.xlsx')
df1 = pd.read_excel(xls, 'Sheet1')
df1=pd.read_excel("MasterExcel.xlsx")
new_header = df1.iloc[0] #grab the first row for the header
df1 = df1[1:] #take the data less the header row
df1.columns = new_header #set the header row as the df header
df1.head()
# Out:
# 0      ID       MakeText              TypeName  \
# 1   976.0  MERCEDES-BENZ               McLaren
# 2  1059.0  MERCEDES-BENZ    ML 350 Inspiration
# 3   524.0           AUDI  S6 Avant quattro 4.2
# 4   608.0           SAAB   9-3 2.0i-16 TS Aero
# 5   726.0        PORSCHE      911 Turbo Cabrio
#
# 0                      TypeNameFull ModelText         ModelTypeText  \
# 1         MERCEDES-BENZ SLR McLaren       SLR           SLR McLaren
# 2  MERCEDES-BENZ ML 350 Inspiration    ML 350    ML 350 Inspiration
# 3         AUDI S6 Avant quattro 4.2        S6  S6 Avant quattro 4.2
# 4          SAAB 9-3 2.0i-16 TS Aero       9-3   9-3 2.0i-16 TS Aero
# 5          PORSCHE 911 Turbo Cabrio       911      911 Turbo Cabrio
#
# 0 Attribute Names Attribute Values                             entity_id
# 1           Seats                2  0001fda6-192b-46a8-bc08-0e833f904eed
# 2              Hp              235  00107c2d-0071-4475-88f0-810133638b7e
# 3    FuelTypeText           Benzin  00126794-a8ef-48fe-93d6-43cfc69fbfb6
# 4             Ccm             1985  00182529-1bf7-4f93-89fa-2e8e634b2c9d
# 5   BodyColorText     schwarz mét.  002d30c2-43f6-4905-868f-160dbc445c56

# %% [markdown]
# # Task 2: Data Normalisation

# %% [markdown]
#  - Normalisation :From the above data it is evident that Normalisation is required in order to achieve the similar meaning with the target dataset.
#      - I have chosen "DriverType" and the "BodyColorText" from the "AttributeNames" and Normalised.
#           - I have set the values in the "DriverType" "Allrad" as 1","Hinterradantrieb" as "2","Vorderradantrieb" as "3" and "null":"0".
#           - Similarly the BodyColorText had German words and I have transformed to English colors just to give the advantage of pulling in the International customers.

# %% [markdown]
#  - These two Attribute names are normalized and mapped accordingly and put into sheet 2 of the MasterExcel.
#  - There is potential to Normalize many other Attributes such as ConsumptionRateText which has attribute value say 14.4 1/100km to just the numbers which could be used in Data analysis to estimate the which models are best in termns of fuel consumption.
#  - Also One could normalize the TypeNameFull to decrease the complexity in retaining the full name.

# %% [markdown]
# Sheet 2 has Normalised Supplier data reflecting normalization of two attributes.

# %%
df2 = pd.read_excel(xls, 'Sheet2')
new_header = df2.iloc[0] #grab the first row for the header
df2 = df2[1:] #take the data less the header row
df2.columns = new_header #set the header row as the df header
df2.head()
# Out:
# 0      ID       MakeText              TypeName  \
# 1   976.0  MERCEDES-BENZ               McLaren
# 2  1059.0  MERCEDES-BENZ    ML 350 Inspiration
# 3   524.0           AUDI  S6 Avant quattro 4.2
# 4   608.0           SAAB   9-3 2.0i-16 TS Aero
# 5   726.0        PORSCHE      911 Turbo Cabrio
#
# 0                      TypeNameFull ModelText         ModelTypeText  \
# 1         MERCEDES-BENZ SLR McLaren       SLR           SLR McLaren
# 2  MERCEDES-BENZ ML 350 Inspiration    ML 350    ML 350 Inspiration
# 3         AUDI S6 Avant quattro 4.2        S6  S6 Avant quattro 4.2
# 4          SAAB 9-3 2.0i-16 TS Aero       9-3   9-3 2.0i-16 TS Aero
# 5          PORSCHE 911 Turbo Cabrio       911      911 Turbo Cabrio
#
# 0 Attribute Names Attribute Values                             entity_id
# 1           Seats                2  0001fda6-192b-46a8-bc08-0e833f904eed
# 2              Hp              235  00107c2d-0071-4475-88f0-810133638b7e
# 3    FuelTypeText           Benzin  00126794-a8ef-48fe-93d6-43cfc69fbfb6
# 4             Ccm             1985  00182529-1bf7-4f93-89fa-2e8e634b2c9d
# 5   BodyColorText            black  002d30c2-43f6-4905-868f-160dbc445c56

# %% [markdown]
# # Task 3: Data Integration

# %% [markdown]
#  - Input: normalised supplier data
#  - Output: integrated supplier data
#       - The supplier data with a specific data schema is transformed into a new dataset with target data schema

# %% [markdown]
# Sheet 3 has target schema data which has the potential to fill in the desired attribute or records depending on the demands.

# %% [markdown]
#  - The new dataset is the target schema which essentially has all the original target datasets and in addition to it 4 more records from the supplier dataset is mapped into the target.
#  - When the information is required one could possibly get the information from the suppliers and fill in the essentials.

# %%
df4=pd.read_excel(xls,"Sheet3")
df4.head()
# Out:
#        carType    color    condition     currency        drive     city  \
# 0  NewSupplier  Unknown  NewSupplier  NewSupplier  NewSupplier  Unknown
# 1  NewSupplier  Unknown  NewSupplier  NewSupplier  NewSupplier  Unknown
# 2  NewSupplier  Unknown  NewSupplier  NewSupplier  NewSupplier  Unknown
# 3  NewSupplier  Unknown  NewSupplier  NewSupplier  NewSupplier  Unknown
# 4  NewSupplier    black  NewSupplier  NewSupplier  NewSupplier  Unknown
#
#        country           make manufacture_year      mileage mileage_unit  \
# 0  NewSupplier  MERCEDES-BENZ      NewSupplier  NewSupplier  NewSupplier
# 1  NewSupplier  MERCEDES-BENZ      NewSupplier  NewSupplier  NewSupplier
# 2  NewSupplier           AUDI      NewSupplier  NewSupplier  NewSupplier
# 3  NewSupplier           SAAB      NewSupplier  NewSupplier  NewSupplier
# 4  NewSupplier        PORSCHE      NewSupplier  NewSupplier  NewSupplier
#
#     model         model_variant price_on_request         type          zip  \
# 0     SLR           SLR McLaren      NewSupplier  NewSupplier  NewSupplier
# 1  ML 350    ML 350 Inspiration      NewSupplier  NewSupplier  NewSupplier
# 2      S6  S6 Avant quattro 4.2      NewSupplier  NewSupplier  NewSupplier
# 3     9-3   9-3 2.0i-16 TS Aero      NewSupplier  NewSupplier  NewSupplier
# 4     911      911 Turbo Cabrio      NewSupplier  NewSupplier  NewSupplier
#
#   manufacture_month fuel_consumption_unit
# 0       NewSupplier           NewSupplier
# 1       NewSupplier           NewSupplier
# 2       NewSupplier           NewSupplier
# 3       NewSupplier           NewSupplier
# 4       NewSupplier           NewSupplier

# %% [markdown]
# # Deliverables:

# %% [markdown]
#  - With this code An Excelsheet workbook with 3 worksheets showing the results of each
# step above (i.e., pre-pro- cessing/normalisation/integration) are saved in Sheet 1,Sheet2 and Sheet3 resüectively
#  - It can also be converted to pandas and different Data Analysis can be done in future.
